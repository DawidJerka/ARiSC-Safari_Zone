# %% [markdown]
# ## Importy

# %%
import os
import time
import random
from enum import Enum

import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from IPython.display import display, clear_output
from PIL import Image, ImageDraw, ImageFont

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import BaseCallback
# Out:
# 2025-06-11 12:11:31.720300: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-11 12:11:31.736298: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749636691.756598 1780732 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749636691.762775 1780732 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749636691.778014 1780732 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749636691.778037 1780732 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749636691.778039 1780732 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749636691.778041 1780732 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-11 12:11:31.783416: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Przygotowanie środowiska
#
# Celem projektu jest stworzenie środowiska odwzorowującego Safari Zone w grze Pokemon. Celem agenta będzie złapanie jak największej ilości pokemonów z ograniczoną liczbą Safari Ball.
#
# ## Akcje agenta
#
# Agent będzie miał do wyboru 3 akcje:
#
# Catch - rzucenie i stracenie Safari Ball w celu podjęcia próby złapania pokemona.
#
# Rock - rzucenie kamienia, który zwiększy szanse na złapanie, ale również na ucieczke pokemona.
#
# Bait - rzucenie przynęty, która zmniejszy szanse uciekczki, ale również zmniejszy szanse złapania pokemona.
#
#
# Akcje zostały zaimplementowane jako enum.

# %%
class TrainerAction(Enum):
    CATCH = 0
    ROCK = 1
    BAIT = 2

# %% [markdown]
# ## Gatunek pokemona
#
# Pokemony pojawiające się w środowisku będą podzielone na kilka rodzajów. W zależności od rodzaju Pokémona będzie on posiadał różne wartości statystyk. Do statystyk pokemonów należą: szansa na złapanie, szansa na ucieczke, level oraz mnożniki skuteczności rock i bait. W zależności od statystyk agent będzie musiał przyjąć inne strategie.

# %%
class PokemonType(Enum):
    PIKACHU = ("Pikachu", 0.4, 0.15, 1.1, 0.9, 7, 5, 15)
    ABRA = ("Abra", 0.2, 0.4, 0.8, 1.5, 4, 10, 20)
    SNORLAX = ("Snorlax", 0.1, 0.05, 1.5, 0.7, 10, 25, 35)
    CHARMANDER = ("Charmander", 0.3, 0.2, 1.0, 1.0, 8, 12, 22)
    MAGIKARP = ("Magikarp", 0.8, 0.3, 0.9, 1.1, 5, 2, 10)

    def __init__(self, name, base_catch_rate, base_escape_rate, bait_effect_multiplier, rock_effect_multiplier, base_turns, min_level, max_level):
        self.pokemon_name = name
        self.base_catch_rate = base_catch_rate
        self.base_escape_rate = base_escape_rate
        self.bait_effect_multiplier = bait_effect_multiplier
        self.rock_effect_multiplier = rock_effect_multiplier
        self.base_turns = base_turns
        self.min_level = min_level
        self.max_level = max_level

    def __str__(self):
        return f"{self.pokemon_name} (Lvl: {self.min_level}-{self.max_level})"

# %% [markdown]
# ## Encounter
#
# Klasa WildPokemon odpowiada za logikę spotkań między Agentem, a Pokemonami. Klasa bierze pokemona i jego podstawowe statystyki, przelicza je w celu zwiększenia lub zmniejszenia trudności złapania w zależności od levelu (większy level -> większa trudność). W zależności od akcji agenta klasa zwiekszy lub zmniejszy statystyki i zdeterminuje czy pokemon został złapany czy uciekł.

# %%
class WildPokemon:
    def __init__(self, pokemon_type: PokemonType):
        self.pokemon_type = pokemon_type
        self.level = random.randint(pokemon_type.min_level, pokemon_type.max_level)
        
        self.current_catch_rate = self._calculate_initial_catch_rate()
        self.current_escape_rate = self._calculate_initial_escape_rate()
        
        self.remaining_turns = pokemon_type.base_turns
        self.turns_elapsed_in_encounter = 0
        self.baits_thrown = 0
        self.rocks_thrown = 0
        
    def _calculate_initial_catch_rate(self): #Obliczanie bazowej szansy na złapanie
        level_penalty = (self.level - self.pokemon_type.min_level) * 0.01 
        return max(0.01, self.pokemon_type.base_catch_rate - level_penalty) 

    def _calculate_initial_escape_rate(self): #Obliczanie bazowej szansy na ucieczke
        level_bonus = (self.level - self.pokemon_type.min_level) * 0.005 
        return min(0.99, self.pokemon_type.base_escape_rate + level_bonus) 

    def perform_action(self, action: TrainerAction) -> tuple[bool, bool]: #Zmienianie wartości statystyk w zależności od akcji
        self.remaining_turns -= 1
        self.turns_elapsed_in_encounter += 1
        
        caught = False
        escaped = False

        if action == TrainerAction.BAIT:
            # BAIT: Zmniejsza szansę na ucieczkę, ale odrobinę zmniejsza szansę na złapanie
            # Zmniejszenie szansy na ucieczkę (im wyższy level, tym mniejszy wpływ)
            escape_decrease_amount = 0.05 * (1 - (self.level / 100.0)) * self.pokemon_type.bait_effect_multiplier
            self.current_escape_rate = max(0.01, self.current_escape_rate - escape_decrease_amount)

            # Odrobinę zmniejsza szansę na złapanie (mniej dotkliwie niż zwiększa ucieczkę)
            catch_decrease_amount = 0.02 * (1 - (self.level / 100.0)) * self.pokemon_type.bait_effect_multiplier
            self.current_catch_rate = max(0.01, self.current_catch_rate - catch_decrease_amount)
            
            # Aktualizuj licznik baitów
            self.baits_thrown += 1 
            
        elif action == TrainerAction.ROCK:
            # ROCK: Zwiększa szansę na złapanie, ale odrobinę zwiększa szansę na ucieczkę
            # Zwiększenie szansy na złapanie (im wyższy level, tym mniejszy wpływ)
            catch_increase_amount = 0.07 * (1 - (self.level / 100.0)) * self.pokemon_type.rock_effect_multiplier
            self.current_catch_rate = min(0.95, self.current_catch_rate + catch_increase_amount)
            
            # Odrobinę zwiększa szansę na ucieczkę (mniej dotkliwie niż zwiększa złapanie)
            escape_increase_amount = 0.03 * (1 - (self.level / 100.0)) * self.pokemon_type.rock_effect_multiplier
            self.current_escape_rate = min(0.99, self.current_escape_rate + escape_increase_amount)

            # Aktualizuj licznik rocków
            self.rocks_thrown += 1

        elif action == TrainerAction.CATCH:
            if random.random() < self.current_catch_rate:
                caught = True
                return caught, escaped # Jeśli pokemon został złapany nie sprawdzamy już czy uciekł
        
        if random.random() < self.current_escape_rate:
            escaped = True
        
        return caught, escaped

    def check_turns_and_escape(self) -> bool:
        if self.remaining_turns <= 0:
            return True
        return False

def get_random_wild_pokemon() -> WildPokemon: #Losowanie rodzaju pokemona
    chosen_type = random.choice(list(PokemonType)) 
    return WildPokemon(chosen_type)

# %% [markdown]
# ## Obrazy i czcionki
#
# Wczytanie obrazków, które będą wykorzystywanie w renderowaniu środowiska.

# %%
IMAGE_DIR = "images" 
BACKGROUND_PATH = os.path.join(IMAGE_DIR, "background.png")
FONT_PATH = os.path.join(IMAGE_DIR, "pokemon_fire_red.ttf")
POKEMON_IMAGE_MAP = {
    PokemonType.PIKACHU: os.path.join(IMAGE_DIR, "pokemon_pikachu.png"),
    PokemonType.ABRA: os.path.join(IMAGE_DIR, "pokemon_abra.png"),
    PokemonType.SNORLAX: os.path.join(IMAGE_DIR, "pokemon_snorlax.png"),
    PokemonType.CHARMANDER: os.path.join(IMAGE_DIR, "pokemon_charmander.png"),
    PokemonType.MAGIKARP: os.path.join(IMAGE_DIR, "pokemon_magikarp.png"),
}

# %% [markdown]
# ## Environment
#
# Środowisko odpowiada za śledzenie obserwacji, stanu oraz nagrody podczas treningu. Na początku inicjalizowane są przestrzeń akcji jaką agent może podjąć (wykorzystany jest enum stworzony wcześniej) oraz przestrzeń obserwacji. Do obserwacji zaliczają się ilość ball, ilość tur, id pokemona oraz jego level. Metoda reset inizializuje/przywraca orginalne wartości zmiennych i przygotowuje środowisko do uruchomienia. Metoda render odpowiada za interfejs graficzny, który wizualizuje dane epizody. Metoda step odpowiada za logike środowiska i zarządza nagrodą jakie agent otrzymywa.

# %%
class SafariZoneEnv(gym.Env):
    metadata = {'render_modes': ['rgb_array', 'human'], 'render_fps': 4}

    def __init__(self, render_mode=None): #Inicjalizacja wszystkich zmiennych + interfejsu graficznego
        super().__init__()

        self.action_space = spaces.Discrete(len(TrainerAction)) #Naprawdę len(TrainerAction) nie dało się 3 xDDDDDDDDDDDDD

        max_safari_balls = 30
        max_turns_in_encounter = max(pt.base_turns for pt in PokemonType) + 5 
        max_pokemon_type_id = len(PokemonType)
        max_pokemon_level = max(pt.max_level for pt in PokemonType)

        self.observation_space = spaces.Dict({
            "safari_balls": spaces.Box(low=0, high=max_safari_balls, shape=(1,), dtype=np.int32),
            "turns_elapsed": spaces.Box(low=0, high=max_turns_in_encounter, shape=(1,), dtype=np.int32),
            "pokemon_type_id": spaces.Discrete(max_pokemon_type_id),
            "pokemon_level": spaces.Box(low=0, high=max_pokemon_level, shape=(1,), dtype=np.int32),
            "baits_thrown_at_pokemon": spaces.Box(low=0, high=max_turns_in_encounter, shape=(1,), dtype=np.int32),
            "rocks_thrown_at_pokemon": spaces.Box(low=0, high=max_turns_in_encounter, shape=(1,), dtype=np.int32)
        })

        self.render_mode = render_mode
        self.safari_balls = 0
        self.caught_pokemon_count = 0
        self.current_pokemon = None

        self.screen_width = 480
        self.screen_height = 224

        if self.render_mode == 'rgb_array':  # Ładowanie wszystkich obrazków
            try:
                self.background_img = Image.open(BACKGROUND_PATH).resize((self.screen_width, self.screen_height)).convert("RGB")
            except FileNotFoundError:
                print(f"Błąd: Nie znaleziono pliku tła pod ścieżką: {BACKGROUND_PATH}")
                self.background_img = Image.new('RGB', (self.screen_width, self.screen_height), color = 'lightblue')
            
            self.pokemon_imgs = {}
            for p_type, path in POKEMON_IMAGE_MAP.items():
                try:
                    self.pokemon_imgs[p_type] = Image.open(path).convert("RGBA").resize((120, 120)) 
                except FileNotFoundError:
                    print(f"Błąd: Nie znaleziono pliku Pokémona pod ścieżką: {path}")
                    self.pokemon_imgs[p_type] = Image.new('RGBA', (120, 120), color = 'red')
            
            try:
                self.font = ImageFont.truetype(FONT_PATH, 32)
            except IOError:
                print(f"Nie znaleziono czcionki {FONT_PATH}, używam domyślnej.")
                self.font = ImageFont.load_default()


    def _get_obs(self):  # Pobranie obswerwacji
        if self.current_pokemon:  # Jeśli istnieje pokemon
            pokemon_type_id = list(PokemonType).index(self.current_pokemon.pokemon_type)
            return {  # Pobranie wszystkich informacji z klasy
                "safari_balls": np.array([self.safari_balls], dtype=np.int32),
                "turns_elapsed": np.array([self.current_pokemon.turns_elapsed_in_encounter], dtype=np.int32),
                "pokemon_type_id": pokemon_type_id,
                "pokemon_level": np.array([self.current_pokemon.level], dtype=np.int32),
                "baits_thrown_at_pokemon": np.array([self.current_pokemon.baits_thrown], dtype=np.int32),
                "rocks_thrown_at_pokemon": np.array([self.current_pokemon.rocks_thrown], dtype=np.int32)
            }
        else:  # Jeśli nie to zerujemy
            return {
                "safari_balls": np.array([0], dtype=np.int32),
                "turns_elapsed": np.array([0], dtype=np.int32),
                "pokemon_type_id": 0, 
                "pokemon_level": np.array([0], dtype=np.int32),
                "baits_thrown_at_pokemon": np.array([0], dtype=np.int32),
                "rocks_thrown_at_pokemon": np.array([0], dtype=np.int32)
            }

    def _get_info(self):
        # Ta metoda zwraca dodatkowe informacje (nie używane przez agenta do podejmowania decyzji)
        return {
            "safari_balls_left": self.safari_balls,
            "caught_pokemon_total": self.caught_pokemon_count,
            "current_pokemon_info": {
                "type": self.current_pokemon.pokemon_type.pokemon_name if self.current_pokemon else "None",
                "level": self.current_pokemon.level if self.current_pokemon else 0,
                "catch_rate": self.current_pokemon.current_catch_rate if self.current_pokemon else 0.0,
                "escape_rate": self.current_pokemon.current_escape_rate if self.current_pokemon else 0.0,
                "remaining_turns": self.current_pokemon.remaining_turns if self.current_pokemon else 0,
                "baits_thrown": self.current_pokemon.baits_thrown if self.current_pokemon else 0,
                "rocks_thrown": self.current_pokemon.rocks_thrown if self.current_pokemon else 0,
            }
        }

    def reset(self, seed=None, options=None):  # Funckja wywoływana przy resecie środowiska
        super().reset(seed=seed)
        # Ustawianie wszystkich wartości na początek
        self.safari_balls = 30
        self.caught_pokemon_count = 0
        self.current_pokemon = get_random_wild_pokemon()

        observation = self._get_obs()
        info = self._get_info()

        if self.render_mode == 'human':  # Renderowanie tekstowe
            print(f"\n--- Rozpoczynasz Safari Zone! ---")
            print(f"Masz {self.safari_balls} Safari Balli.")
            print(f"Pojawił się dziki {self.current_pokemon.pokemon_type.pokemon_name} (Lvl: {self.current_pokemon.level})!")
            print(f"Początkowa Szansa na złapanie: {self.current_pokemon.current_catch_rate:.2f}")
            print(f"Początkowa Szansa na ucieczkę: {self.current_pokemon.current_escape_rate:.2f}")
            print(f"Tury do ucieczki: {self.current_pokemon.remaining_turns}")
            print(f"Upłynięte tury: {self.current_pokemon.turns_elapsed_in_encounter}")
        
        return observation, info

    def step(self, action):  # Funkcja step, czyli jaka logika się dzieje przy każdym kroku
        reward = 0 
        terminated = False 
        truncated = False 

        action_enum = TrainerAction(action)

        if action_enum == TrainerAction.CATCH:
            self.safari_balls -= 1
            if self.render_mode == 'human':
                print(f"Rzucono Safari Ballem! Pozostało: {self.safari_balls}")

        caught, escaped = self.current_pokemon.perform_action(action_enum)  # Wysyłanie akcji agenta do perform_action()
        
        if caught:  # Jeśli złapał +100 nagrody
            reward = 100.0
            self.caught_pokemon_count += 1
            if self.render_mode == 'human':
                print(f"Złapałeś {self.current_pokemon.pokemon_type.pokemon_name}!")
        elif escaped:  # Jeśli pokemon uciekł -50 nagrody
            reward = -50.0
            if self.render_mode == 'human':
                print(f"{self.current_pokemon.pokemon_type.pokemon_name} uciekł!")
        else:  # W zależności od akcji lekka nagroda
            if action_enum == TrainerAction.BAIT:  # Za przynęte nagroda na zachęte
                reward = 0.5
                if self.render_mode == 'human':
                    print("Rzucono Przynętę. Pokémon jest spokojniejszy.")
            elif action_enum == TrainerAction.ROCK:  # Za kamień nagroda na zachęte
                reward = 0.2
                if self.render_mode == 'human':
                    print("Rzucono Kamieniem. Pokémon jest agresywniejszy.")
            elif action_enum == TrainerAction.CATCH:  # Minusowa nagroda żeby nie wyrzucił wszystkich ball odrazu
                reward = -5.0
                if self.render_mode == 'human':
                    print("Próba złapania nieudana.")
            
        encounter_ended = caught or escaped or self.current_pokemon.check_turns_and_escape()

        if encounter_ended and not caught and not escaped:  # Minusowa nagroda jeśli pokemon ucieknie przez koniec tur
            reward -= 30.0
            if self.render_mode == 'human':
                print(f"{self.current_pokemon.pokemon_type.pokemon_name} uciekł (brak tur)!")

        if self.safari_balls <= 0:  # Jak skończą się Safari Balls to kończymy
            terminated = True 
            if self.render_mode == 'human':
                print("Skończyły Ci się Safari Balle! Koniec gry.")
        
        if encounter_ended and not terminated:  # Jeśli pokemon uciekł, ale nie skończyła się liczba ball, losowany jest nowy pokemon
            self.current_pokemon = get_random_wild_pokemon()
            if self.render_mode == 'human':
                print(f"\n--- Pojawił się dziki {self.current_pokemon.pokemon_type.pokemon_name} (Lvl: {self.current_pokemon.level})! ---")
                print(f"Początkowa Szansa na złapanie: {self.current_pokemon.current_catch_rate:.2f}")
                print(f"Początkowa Szansa na ucieczkę: {self.current_pokemon.current_escape_rate:.2f}")
                print(f"Tury do ucieczki: {self.current_pokemon.remaining_turns}")
                print(f"Upłynięte tury: {self.current_pokemon.turns_elapsed_in_encounter}")

        observation = self._get_obs()
        info = self._get_info()

        return observation, reward, terminated, truncated, info

    def render(self):  # Tworzenie interfejsu graficznego
        if self.render_mode == 'rgb_array':
            return np.array(self._render_frame().convert("RGB"))
        elif self.render_mode == 'human':  # Grafika wyświetlana w trybie "grania przez człowieka"
            print(f"\n--- Stan Gry ---")
            print(f"Pozostałych Safari Balli: {self.safari_balls}")
            print(f"Złapane Pokemony: {self.caught_pokemon_count}")
            if self.current_pokemon:
                print(f"Aktualny Pokemon: {self.current_pokemon.pokemon_type.pokemon_name} (Lvl: {self.current_pokemon.level})")
                print(f"  Szansa na złapanie: {self.current_pokemon.current_catch_rate:.2f}")
                print(f"  Szansa na ucieczkę: {self.current_pokemon.current_escape_rate:.2f}")
                print(f"  Tury do ucieczki: {self.current_pokemon.remaining_turns}")
                print(f"  Upłynięte tury w spotkaniu: {self.current_pokemon.turns_elapsed_in_encounter}")
            else:
                print("Brak aktywnego Pokemona.")
            print("----------------")
            return None
        else:
            return None 

    def _render_frame(self):  # Metoda, która wyświetli grafike kiedy tryb "RGB"
        canvas = self.background_img.copy()
        draw = ImageDraw.Draw(canvas)

        # Wczytywanie obrazka pokemona
        pokemon_img = None
        if self.current_pokemon:
            pokemon_img = self.pokemon_imgs.get(self.current_pokemon.pokemon_type)
        
        if pokemon_img:
            pokemon_x = 280
            pokemon_y = 34
            canvas.paste(pokemon_img, (pokemon_x, pokemon_y), pokemon_img)

        obs = self._get_obs()
        
        # Wczytanie tekstu dla interfejsu
        text_color = (0, 0, 0)

        # Typ Pokemona
        pokemon_type_text = f"{self.current_pokemon.pokemon_type.pokemon_name.upper()}" if self.current_pokemon else "NONE"
        draw.text((40, 34), pokemon_type_text, font=self.font, fill=text_color)

        # Poziom Pokemona
        pokemon_level_text = f"{self.current_pokemon.level}" if self.current_pokemon else "N/A"
        draw.text((187, 34), pokemon_level_text, font=self.font, fill=text_color)

        # Safari Balls
        safari_balls_text = f"Safari Balls: {obs['safari_balls'][0]}"
        draw.text((280, 153), safari_balls_text, font=self.font, fill=text_color)

        # Ilość tur
        turns_text = f"Turns elapsed: {obs['turns_elapsed'][0]}"
        draw.text((280, 180), turns_text, font=self.font, fill=text_color)
        
        return canvas

    def close(self):
        pass

# %% [markdown]
# ## Callback
#
# Clasa callback pomaga zapisywać wyniki podczas ćwiczenia modelu.

# %%
class CustomCallback(BaseCallback):
    def __init__(self, verbose: int = 0):
        super().__init__(verbose)
        self.rewards_history = []
        self.caught_pokemon_history = []
        self.episode_num = 0
        self.ep_rewards = 0
        self.ep_caught = 0

    def _on_step(self) -> bool:
        if self.locals['dones'].any(): 
            for i, done_env in enumerate(self.locals['dones']):
                if done_env:
                    self.episode_num += 1
                    self.rewards_history.append(self.ep_rewards)
                    info = self.locals['infos'][i]
                    self.caught_pokemon_history.append(info['caught_pokemon_total'])
                    
                    # Resetowanie metryk
                    self.ep_rewards = 0
                    self.ep_caught = 0

                    if self.episode_num % 100 == 0:  # Uśrednienie metryk ściągniętych co 100 episode
                        mean_reward = np.mean(self.rewards_history[-100:]) if len(self.rewards_history) >= 100 else np.mean(self.rewards_history)
                        mean_caught = np.mean(self.caught_pokemon_history[-100:]) if len(self.caught_pokemon_history) >= 100 else np.mean(self.caught_pokemon_history)
                        print(f"Episode: {self.episode_num}, Mean Reward (last 100): {mean_reward:.2f}, Mean Caught (last 100): {mean_caught:.2f}")

        # Zsumowanie nagród
        self.ep_rewards += self.locals['rewards'].sum() 

        # Zsumowanie złapanych pokemonów
        self.ep_caught = self.training_env.get_attr('caught_pokemon_count')[0] 

        return True

# %% [markdown]
# # Trening
#
# Tutaj użyty został algorytm PPO w celu nauczenia modelu działania w stworzonym środowisku. Wytrenowany model jest testowany na 100 epizodach i wyniki testów zostają wizualizowane.

# %%
if __name__ == "__main__":
    env = make_vec_env(SafariZoneEnv, n_envs=1, seed=42, env_kwargs={'render_mode': None})  # Inicjowanie środowiska

    model = PPO("MultiInputPolicy", env, verbose=1, tensorboard_log="./ppo_safari_zone_tensorboard/", learning_rate=0.0003)  # Wybrany algorytm to PPO

    total_timesteps = 1_000_000
    
    callback = CustomCallback() # Inicjowanie callback

    print(f"\n--- Rozpoczynam trening agenta PPO na {total_timesteps} kroków ---")
    start_time = time.time()
    
    model.learn(total_timesteps=total_timesteps, callback=callback)  # Nauka modelu
    
    end_time = time.time()
    print(f"\n--- Trening zakończony! Czas: {end_time - start_time:.2f} sekundy ---")

    model.save("ppo_safari_zone_model")
    print("Model został zapisany jako 'ppo_safari_zone_model.zip'")

    print("\n--- Ocena wytrenowanego agenta ---")
    num_eval_episodes = 100
    eval_rewards = []
    eval_caught_pokemon = []

    # W celu oceny nauczonego modelu zasymulowane zostały 100 epizodów
    eval_env = SafariZoneEnv(render_mode='rgb_array')

    for i in range(num_eval_episodes):
        obs, info = eval_env.reset()
        done = False
        current_eval_reward = 0
        while not done:
            obs_for_predict = {} # Przygotowanie obserwacji do wrzucenia do modelu
            for k, v in obs.items():
                if isinstance(v, np.ndarray):
                    obs_for_predict[k] = np.expand_dims(v, axis=0)
                elif isinstance(v, int):
                    obs_for_predict[k] = np.array([v], dtype=np.int64)
                else:
                    obs_for_predict[k] = np.expand_dims(np.array(v), axis=0)


            action, _states = model.predict(obs_for_predict, deterministic=True) # Wrzucenie obserwacji do modelu i wyciągnięcie akcji

            obs, reward, terminated, truncated, info = eval_env.step(action[0]) 
            done = terminated or truncated
            current_eval_reward += reward
            
        eval_rewards.append(current_eval_reward)
        eval_caught_pokemon.append(info['caught_pokemon_total']) 

    avg_eval_reward = np.mean(eval_rewards)
    avg_eval_caught = np.mean(eval_caught_pokemon)
    std_eval_reward = np.std(eval_rewards)
    std_eval_caught = np.std(eval_caught_pokemon)

    print(f"Średnia nagroda wytrenowanego agenta (przez {num_eval_episodes} epizodów): {avg_eval_reward:.2f} (Std Dev: {std_eval_reward:.2f})")
    print(f"Średnia liczba złapanych Pokémonów wytrenowanego agenta: {avg_eval_caught:.2f} (Std Dev: {std_eval_caught:.2f})")
    print(f"Maksymalna nagroda: {np.max(eval_rewards):.2f}, Min nagroda: {np.min(eval_rewards):.2f}")
    print(f"Maks złapane: {np.max(eval_caught_pokemon):.2f}, Min złapane: {np.min(eval_caught_pokemon):.2f}")


    # Wizualizacja wyników treningu i porównanie
    fig = make_subplots(rows=2, cols=1, 
                        subplot_titles=("Całkowita Nagroda na Epizod (Trening PPO)", 
                                        "Liczba Złapanych Pokémonów na Epizod (Trening PPO)"))

    # Wykres nagród podczas treningu
    fig.add_trace(go.Scatter(y=callback.rewards_history, mode='lines', name='Nagroda epizodu'),
                    row=1, col=1)
    fig.update_xaxes(title_text="Numer Epizodu", row=1, col=1)
    fig.update_yaxes(title_text="Całkowita Nagroda", row=1, col=1)

    # Wykres złapanych Pokémonów podczas treningu
    fig.add_trace(go.Scatter(y=callback.caught_pokemon_history, mode='lines', name='Złapane Pokemony'),
                    row=2, col=1)
    fig.update_xaxes(title_text="Numer Epizodu", row=2, col=1)
    fig.update_yaxes(title_text="Liczba Złapanych Pokémonów", row=2, col=1)

    fig.update_layout(title_text=f"Postępy treningu PPO w Safari Zone ({total_timesteps} kroków)", 
                      height=800, showlegend=False)

    fig.write_html("ppo_safari_zone_training_progress.html")
    print("\nWykresy postępów treningu zostały zapisane do pliku 'ppo_safari_zone_training_progress.html'")

    # Wykresy rozkładów dla wytrenowanego agenta
    fig_eval_rewards = go.Figure(data=[go.Histogram(x=eval_rewards, name='Nagrody PPO', marker_color='purple', opacity=0.7)])
    fig_eval_rewards.update_layout(title_text=f"Rozkład nagród dla wytrenowanego agenta PPO ({num_eval_episodes} epizodów)",
                                   xaxis_title_text="Całkowita Nagroda", yaxis_title_text="Częstość")
    fig_eval_rewards.write_html("ppo_safari_zone_eval_rewards_distribution.html")
    print("Wykres rozkładu nagród wytrenowanego agenta zapisano do 'ppo_safari_zone_eval_rewards_distribution.html'")

    fig_eval_caught = go.Figure(data=[go.Histogram(x=eval_caught_pokemon, name='Złapane Pokemony PPO', marker_color='orange', opacity=0.7, nbinsx=max(eval_caught_pokemon) + 1)])
    fig_eval_caught.update_layout(title_text=f"Rozkład złapanych Pokémonów dla wytrenowanego agenta PPO ({num_eval_episodes} epizodów)",
                                   xaxis_title_text="Liczba Złapanych Pokémonów", yaxis_title_text="Częstość")
    fig_eval_caught.write_html("ppo_safari_zone_eval_caught_distribution.html")
    print("Wykres rozkładu złapanych Pokémonów wytrenowanego agenta zapisano do 'ppo_safari_zone_eval_caught_distribution.html'")

    
    env.close() 
    eval_env.close()
# Out:
# Using cuda device
#
# --- Rozpoczynam trening agenta PPO na 1000000 kroków ---
# Logging to ./ppo_safari_zone_tensorboard/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.5     |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    fps             | 27       |
# |    iterations      | 1        |
# |    time_elapsed    | 73       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.6        |
# |    ep_rew_mean          | -96.2       |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 2           |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011214526 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -2.43e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.8e+03     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 9.48e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | -7.66        |
# | time/                   |              |
# |    fps                  | 23           |
# |    iterations           | 3            |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0120361475 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00221      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.61e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 1.18e+04     |
# ------------------------------------------
# Episode: 100, Mean Reward (last 100): 13.73, Mean Caught (last 100): 7.22
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.1        |
# |    ep_rew_mean          | 78.1        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 4           |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013437783 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0193      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 1.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 5           |
# |    time_elapsed         | 443         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015055641 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.0204      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.46e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 1.28e+04    |
# -----------------------------------------
# Episode: 200, Mean Reward (last 100): 219.61, Mean Caught (last 100): 7.06
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.4         |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 6            |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0060996977 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.0318       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.48e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 1.62e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.2        |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 7           |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008376138 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.0373      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.55e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00842    |
# |    value_loss           | 1.24e+04    |
# -----------------------------------------
# Episode: 300, Mean Reward (last 100): 289.53, Mean Caught (last 100): 6.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.8        |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 8           |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005339111 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.0344      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.68e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 2.01e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.3         |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 9            |
# |    time_elapsed         | 812          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0028787572 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.65        |
# |    explained_variance   | 0.0275       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.92e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 1.77e+04     |
# ------------------------------------------
# Episode: 400, Mean Reward (last 100): 257.85, Mean Caught (last 100): 6.44
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.2        |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 10          |
# |    time_elapsed         | 904         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004380378 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.0323      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 1.87e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.9         |
# |    ep_rew_mean          | 295          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 11           |
# |    time_elapsed         | 996          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0013913618 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.0453       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 1.94e+04     |
# ------------------------------------------
# Episode: 500, Mean Reward (last 100): 310.36, Mean Caught (last 100): 6.84
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.4         |
# |    ep_rew_mean          | 329          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 12           |
# |    time_elapsed         | 1089         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0032764198 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.0761       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.13e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 1.93e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.6         |
# |    ep_rew_mean          | 293          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 13           |
# |    time_elapsed         | 1181         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0022512164 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.0872       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.17e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 1.9e+04      |
# ------------------------------------------
# Episode: 600, Mean Reward (last 100): 307.12, Mean Caught (last 100): 6.48
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.5         |
# |    ep_rew_mean          | 317          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 14           |
# |    time_elapsed         | 1274         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0025386875 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.4         |
# |    explained_variance   | 0.0815       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+04      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 2.04e+04     |
# ------------------------------------------
# Episode: 700, Mean Reward (last 100): 303.98, Mean Caught (last 100): 6.56
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 15           |
# |    time_elapsed         | 1366         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0018644668 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | 0.0676       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 2.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.7         |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 16           |
# |    time_elapsed         | 1458         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0009474313 |
# |    clip_fraction        | 0.00215      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.0472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.65e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 2.04e+04     |
# ------------------------------------------
# Episode: 800, Mean Reward (last 100): 274.18, Mean Caught (last 100): 6.23
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32          |
# |    ep_rew_mean          | 304         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 17          |
# |    time_elapsed         | 1550        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.001223858 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0.0969      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+04     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 1.79e+04    |
# -----------------------------------------
# Episode: 900, Mean Reward (last 100): 321.34, Mean Caught (last 100): 6.53
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.2         |
# |    ep_rew_mean          | 321          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 18           |
# |    time_elapsed         | 1643         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0006427438 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.309       |
# |    explained_variance   | 0.0953       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.17e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 2.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.5         |
# |    ep_rew_mean          | 306          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 19           |
# |    time_elapsed         | 1737         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0010958923 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.27e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 1.99e+04     |
# ------------------------------------------
# Episode: 1000, Mean Reward (last 100): 314.11, Mean Caught (last 100): 6.58
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 33.2          |
# |    ep_rew_mean          | 318           |
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 20            |
# |    time_elapsed         | 1829          |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00093676476 |
# |    clip_fraction        | 0.0149        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.373        |
# |    explained_variance   | 0.134         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+04      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 1.82e+04      |
# -------------------------------------------

# %% [markdown]
# # Tryb interaktywny
#
# Tryb stworzony do testowania środowiska.

# %%
print("--- Tryb interaktywnego renderowania ---")
print("Wpisz numer akcji i naciśnij Enter:")
print("0: CATCH (Rzuć Safari Ballem)")
print("1: ROCK (Rzuć kamieniem)")
print("2: BAIT (Rzuć przynętę)")
print("---------------------------------------")

env_interactive = SafariZoneEnv(render_mode='rgb_array')  # Użyj renderowania graficznego
observation, info = env_interactive.reset()

done = False
while not done:
    clear_output(wait=True)  # Wyczyść poprzednią klatkę w Jupyterze

    # Wyświetl aktualną klatkę gry
    frame = env_interactive.render()
    if frame is not None:
        display(Image.fromarray(frame))
    else:
        print("Błąd renderowania klatki.")
        break  # Przerwij, jeśli renderowanie się nie powiedzie

    # Wyświetl aktualny stan tekstowy
    print(f"\n--- Stan Gry ---")
    print(f"Pozostałych Safari Balli: {env_interactive.safari_balls}")
    print(f"Złapane Pokemony: {env_interactive.caught_pokemon_count}")
    if env_interactive.current_pokemon:
        print(f"Aktualny Pokemon: {env_interactive.current_pokemon.pokemon_type.pokemon_name.upper()} (Lvl: {env_interactive.current_pokemon.level})")
        print(f"  Szansa na złapanie: {env_interactive.current_pokemon.current_catch_rate:.2f}")
        print(f"  Szansa na ucieczkę: {env_interactive.current_pokemon.current_escape_rate:.2f}")
        print(f"  Tury do ucieczki: {env_interactive.current_pokemon.remaining_turns}")
        print(f"  Upłynięte tury w spotkaniu: {env_interactive.current_pokemon.turns_elapsed_in_encounter}")
    else:
        print("Brak aktywnego Pokemona.")
    print("----------------")


    try:
        action_input = input("Twoja akcja (0:CATCH, 1:ROCK, 2:BAIT): ")
        action = int(action_input)
        if action not in [0, 1, 2]:
            print("Nieprawidłowa akcja. Wybierz 0, 1 lub 2.")
            time.sleep(1)
            continue
    except ValueError:
        print("Nieprawidłowy input. Wpisz liczbę.")
        time.sleep(1)
        continue

    observation, reward, terminated, truncated, info = env_interactive.step(action)
    done = terminated or truncated

    # Krótka pauza, żeby zobaczyć zmianę
    time.sleep(0.5)

print("\n--- Gra zakończona! ---")
print(f"Całkowita liczba złapanych Pokémonów: {env_interactive.caught_pokemon_count}")
print(f"Ostateczny stan: {info}")

env_interactive.close()
# Out:
# <PIL.Image.Image image mode=RGB size=480x224>
# --- Stan Gry ---
# Pozostałych Safari Balli: 30
# Złapane Pokemony: 0
# Aktualny Pokemon: PIKACHU (Lvl: 15)
#   Szansa na złapanie: 0.30
#   Szansa na ucieczkę: 0.20
#   Tury do ucieczki: 7
#   Upłynięte tury w spotkaniu: 0
# ----------------

# %% [markdown]
# # Sprawdzenie wydajności losowego agenta
#
# Sprawdzanie jak radzi sobie losowy agent w stworzonym środowisku.

# %%
print("--- Empiryczne sprawdzenie wydajności losowego agenta ---")

# Liczba epizodów do symulacji
num_simulations = 1_000_000

# Listy do przechowywania wyników
random_rewards = []
random_caught_pokemon = []

# Utworzenie środowiska dla symulacji
# Ustawiamy render_mode na None, żeby nie spowalniać symulacji graficznym renderowaniem
env_random_agent = SafariZoneEnv(render_mode=None)

for i in range(num_simulations):
    observation, info = env_random_agent.reset()
    done = False
    current_episode_reward = 0
    current_episode_caught = 0  # Śledzimy złapane Pokemony w bieżącym epizodzie

    while not done:
        # Agent podejmuje losową akcję (0: CATCH, 1: ROCK, 2: BAIT)
        action = env_random_agent.action_space.sample()

        observation, reward, terminated, truncated, info = env_random_agent.step(action)
        done = terminated or truncated

        current_episode_reward += reward
        # Aktualizuj liczbę złapanych Pokémonów z info, które jest zwracane przy zakończeniu epizodu
        # lub w każdym kroku, jeśli środowisko tak zwraca (u nas info['caught_pokemon_total'])
        current_episode_caught = info['caught_pokemon_total']

    random_rewards.append(current_episode_reward)
    random_caught_pokemon.append(current_episode_caught)

    if (i + 1) % 100 == 0:
        print(f"Zakończono {i + 1}/{num_simulations} symulacji.")

# Obliczanie i wyświetlanie statystyk
avg_random_reward = np.mean(random_rewards)
std_random_reward = np.std(random_rewards)
avg_random_caught = np.mean(random_caught_pokemon)
std_random_caught = np.std(random_caught_pokemon)

print("\n--- Wyniki dla losowego agenta ---")
print(f"Liczba symulacji: {num_simulations}")
print(f"Średnia całkowita nagroda na epizod: {avg_random_reward:.2f} (Std Dev: {std_random_reward:.2f})")
print(f"Średnia liczba złapanych Pokémonów na epizod: {avg_random_caught:.2f} (Std Dev: {std_random_caught:.2f})")
print(f"Maksymalna nagroda w epizodzie: {np.max(random_rewards):.2f}")
print(f"Minimalna nagroda w epizodzie: {np.min(random_rewards):.2f}")
print(f"Maksymalna liczba złapanych Pokémonów w epizodzie: {int(np.max(random_caught_pokemon))}")
print(f"Minimalna liczba złapanych Pokémonów w epizodzie: {int(np.min(random_caught_pokemon))}")

env_random_agent.close()
print("\nSymulacja losowego agenta zakończona.")

print("\n--- Generowanie wykresów Plotly dla losowego agenta ---")

# Wykres rozkładu nagród dla losowego agenta
fig_random_rewards = go.Figure(data=[
    go.Histogram(
        x=random_rewards,
        name='Nagrody Losowego Agenta',
        marker_color='skyblue',
        opacity=0.7,
        xbins=dict(size=10)  # Rozmiar przedziałów
    )
])
fig_random_rewards.update_layout(
    title_text=f"Rozkład całkowitych nagród na epizod (Losowy Agent, {num_simulations} epizodów)",
    xaxis_title_text="Całkowita Nagroda w Epizodzie",
    yaxis_title_text="Częstość",
    bargap=0.05  # Odstęp między słupkami
)
fig_random_rewards.write_html("random_agent_rewards_distribution.html")
print("Wykres rozkładu nagród losowego agenta został zapisany do 'random_agent_rewards_distribution.html'")

# Wykres rozkładu złapanych Pokémonów dla losowego agenta
fig_random_caught = go.Figure(data=[
    go.Histogram(
        x=random_caught_pokemon,
        name='Złapane Pokemony Losowego Agenta',
        marker_color='lightcoral',
        opacity=0.7,
        nbinsx=int(np.max(random_caught_pokemon)) + 1 if random_caught_pokemon else 1,  # Jeden słupek na każdą możliwą liczbę złapanych Pokémonów
        xbins=dict(start=0, end=int(np.max(random_caught_pokemon)) + 0.5, size=1)
    )
])
fig_random_caught.update_layout(
    title_text=f"Rozkład liczby złapanych Pokémonów na epizod (Losowy Agent, {num_simulations} epizodów)",
    xaxis_title_text="Liczba Złapanych Pokémonów",
    yaxis_title_text="Częstość",
    bargap=0.05
)
fig_random_caught.write_html("random_agent_caught_distribution.html")
print("Wykres rozkładu złapanych Pokémonów losowego agenta został zapisany do 'random_agent_caught_distribution.html'")

print("\nGenerowanie wykresów zakończone.")
# Out:
# --- Empiryczne sprawdzenie wydajności losowego agenta ---
# Zakończono 100/1000000 symulacji.
# Zakończono 200/1000000 symulacji.
# Zakończono 300/1000000 symulacji.
# Zakończono 400/1000000 symulacji.
# Zakończono 500/1000000 symulacji.
# Zakończono 600/1000000 symulacji.
# Zakończono 700/1000000 symulacji.
# Zakończono 800/1000000 symulacji.
# Zakończono 900/1000000 symulacji.
# Zakończono 1000/1000000 symulacji.
# Zakończono 1100/1000000 symulacji.
# Zakończono 1200/1000000 symulacji.
# Zakończono 1300/1000000 symulacji.
# Zakończono 1400/1000000 symulacji.
# Zakończono 1500/1000000 symulacji.
# Zakończono 1600/1000000 symulacji.
# Zakończono 1700/1000000 symulacji.
# Zakończono 1800/1000000 symulacji.
# Zakończono 1900/1000000 symulacji.
# Zakończono 2000/1000000 symulacji.
# Zakończono 2100/1000000 symulacji.
# Zakończono 2200/1000000 symulacji.
# Zakończono 2300/1000000 symulacji.
# Zakończono 2400/1000000 symulacji.
# Zakończono 2500/1000000 symulacji.
# Zakończono 2600/1000000 symulacji.
# Zakończono 2700/1000000 symulacji.
# Zakończono 2800/1000000 symulacji.
# Zakończono 2900/1000000 symulacji.
# Zakończono 3000/1000000 symulacji.
# Zakończono 3100/1000000 symulacji.
# Zakończono 3200/1000000 symulacji.
# Zakończono 3300/1000000 symulacji.
# Zakończono 3400/1000000 symulacji.
# Zakończono 3500/1000000 symulacji.
# Zakończono 3600/1000000 symulacji.
# Zakończono 3700/1000000 symulacji.
# Zakończono 3800/1000000 symulacji.
# Zakończono 3900/1000000 symulacji.
# Zakończono 4000/1000000 symulacji.
# Zakończono 4100/1000000 symulacji.
# Zakończono 4200/1000000 symulacji.
# Zakończono 4300/1000000 symulacji.
# Zakończono 4400/1000000 symulacji.
# Zakończono 4500/1000000 symulacji.
# Zakończono 4600/1000000 symulacji.
# Zakończono 4700/1000000 symulacji.
# Zakończono 4800/1000000 symulacji.
# Zakończono 4900/1000000 symulacji.
# Zakończono 5000/1000000 symulacji.
# Zakończono 5100/1000000 symulacji.
# Zakończono 5200/1000000 symulacji.
# Zakończono 5300/1000000 symulacji.
# Zakończono 5400/1000000 symulacji.
# Zakończono 5500/1000000 symulacji.
# Zakończono 5600/1000000 symulacji.
# Zakończono 5700/1000000 symulacji.
# Zakończono 5800/1000000 symulacji.
# Zakończono 5900/1000000 symulacji.
# Zakończono 6000/1000000 symulacji.
# Zakończono 6100/1000000 symulacji.
# Zakończono 6200/1000000 symulacji.
# Zakończono 6300/1000000 symulacji.
# Zakończono 6400/1000000 symulacji.
# Zakończono 6500/1000000 symulacji.
# Zakończono 6600/1000000 symulacji.
# Zakończono 6700/1000000 symulacji.
# Zakończono 6800/1000000 symulacji.
# Zakończono 6900/1000000 symulacji.
# Zakończono 7000/1000000 symulacji.
# Zakończono 7100/1000000 symulacji.
# Zakończono 7200/1000000 symulacji.
# Zakończono 7300/1000000 symulacji.
# Zakończono 7400/1000000 symulacji.
# Zakończono 7500/1000000 symulacji.
# Zakończono 7600/1000000 symulacji.
# Zakończono 7700/1000000 symulacji.
# Zakończono 7800/1000000 symulacji.
# Zakończono 7900/1000000 symulacji.
# Zakończono 8000/1000000 symulacji.
# Zakończono 8100/1000000 symulacji.
# Zakończono 8200/1000000 symulacji.
# Zakończono 8300/1000000 symulacji.
# Zakończono 8400/1000000 symulacji.
# Zakończono 8500/1000000 symulacji.
# Zakończono 8600/1000000 symulacji.
# Zakończono 8700/1000000 symulacji.
# Zakończono 8800/1000000 symulacji.
# Zakończono 8900/1000000 symulacji.
# Zakończono 9000/1000000 symulacji.
# Zakończono 9100/1000000 symulacji.
# Zakończono 9200/1000000 symulacji.
# Zakończono 9300/1000000 symulacji.
# Zakończono 9400/1000000 symulacji.
# Zakończono 9500/1000000 symulacji.
# Zakończono 9600/1000000 symulacji.
# Zakończono 9700/1000000 symulacji.
# Zakończono 9800/1000000 symulacji.
# Zakończono 9900/1000000 symulacji.
# Zakończono 10000/1000000 symulacji.
# Zakończono 10100/1000000 symulacji.
# Zakończono 10200/1000000 symulacji.
# Zakończono 10300/1000000 symulacji.
# Zakończono 10400/1000000 symulacji.
# Zakończono 10500/1000000 symulacji.
# Zakończono 10600/1000000 symulacji.
# Zakończono 10700/1000000 symulacji.
# Zakończono 10800/1000000 symulacji.
# Zakończono 10900/1000000 symulacji.
# Zakończono 11000/1000000 symulacji.
# Zakończono 11100/1000000 symulacji.
# Zakończono 11200/1000000 symulacji.
# Zakończono 11300/1000000 symulacji.
# Zakończono 11400/1000000 symulacji.
# Zakończono 11500/1000000 symulacji.
# Zakończono 11600/1000000 symulacji.
# Zakończono 11700/1000000 symulacji.
# Zakończono 11800/1000000 symulacji.
# Zakończono 11900/1000000 symulacji.
# Zakończono 12000/1000000 symulacji.
# Zakończono 12100/1000000 symulacji.
# Zakończono 12200/1000000 symulacji.
# Zakończono 12300/1000000 symulacji.
# Zakończono 12400/1000000 symulacji.
# Zakończono 12500/1000000 symulacji.
# Zakończono 12600/1000000 symulacji.
# Zakończono 12700/1000000 symulacji.
# Zakończono 12800/1000000 symulacji.
# Zakończono 12900/1000000 symulacji.
# Zakończono 13000/1000000 symulacji.
# Zakończono 13100/1000000 symulacji.
# Zakończono 13200/1000000 symulacji.
# Zakończono 13300/1000000 symulacji.
# Zakończono 13400/1000000 symulacji.
# Zakończono 13500/1000000 symulacji.
# Zakończono 13600/1000000 symulacji.
# Zakończono 13700/1000000 symulacji.
# Zakończono 13800/1000000 symulacji.
# Zakończono 13900/1000000 symulacji.
# Zakończono 14000/1000000 symulacji.
# Zakończono 14100/1000000 symulacji.
# Zakończono 14200/1000000 symulacji.
# Zakończono 14300/1000000 symulacji.
# Zakończono 14400/1000000 symulacji.
# Zakończono 14500/1000000 symulacji.
# Zakończono 14600/1000000 symulacji.
# Zakończono 14700/1000000 symulacji.
# Zakończono 14800/1000000 symulacji.
# Zakończono 14900/1000000 symulacji.
# Zakończono 15000/1000000 symulacji.
# Zakończono 15100/1000000 symulacji.
# Zakończono 15200/1000000 symulacji.
# Zakończono 15300/1000000 symulacji.
# Zakończono 15400/1000000 symulacji.
# Zakończono 15500/1000000 symulacji.
# Zakończono 15600/1000000 symulacji.
# Zakończono 15700/1000000 symulacji.
# Zakończono 15800/1000000 symulacji.
# Zakończono 15900/1000000 symulacji.
# Zakończono 16000/1000000 symulacji.
# Zakończono 16100/1000000 symulacji.
# Zakończono 16200/1000000 symulacji.
# Zakończono 16300/1000000 symulacji.
# Zakończono 16400/1000000 symulacji.
# Zakończono 16500/1000000 symulacji.
# Zakończono 16600/1000000 symulacji.
# Zakończono 16700/1000000 symulacji.
# Zakończono 16800/1000000 symulacji.
# Zakończono 16900/1000000 symulacji.
# Zakończono 17000/1000000 symulacji.
# Zakończono 17100/1000000 symulacji.
# Zakończono 17200/1000000 symulacji.
# Zakończono 17300/1000000 symulacji.
# Zakończono 17400/1000000 symulacji.
# Zakończono 17500/1000000 symulacji.
# Zakończono 17600/1000000 symulacji.
# Zakończono 17700/1000000 symulacji.
# Zakończono 17800/1000000 symulacji.
# Zakończono 17900/1000000 symulacji.
# Zakończono 18000/1000000 symulacji.
# Zakończono 18100/1000000 symulacji.
# Zakończono 18200/1000000 symulacji.
# Zakończono 18300/1000000 symulacji.
# Zakończono 18400/1000000 symulacji.
# Zakończono 18500/1000000 symulacji.
# Zakończono 18600/1000000 symulacji.
# Zakończono 18700/1000000 symulacji.
# Zakończono 18800/1000000 symulacji.
# Zakończono 18900/1000000 symulacji.
# Zakończono 19000/1000000 symulacji.
# Zakończono 19100/1000000 symulacji.
# Zakończono 19200/1000000 symulacji.
# Zakończono 19300/1000000 symulacji.
# Zakończono 19400/1000000 symulacji.
# Zakończono 19500/1000000 symulacji.
# Zakończono 19600/1000000 symulacji.
# Zakończono 19700/1000000 symulacji.
# Zakończono 19800/1000000 symulacji.
# Zakończono 19900/1000000 symulacji.
# Zakończono 20000/1000000 symulacji.
# Zakończono 20100/1000000 symulacji.
# Zakończono 20200/1000000 symulacji.
# Zakończono 20300/1000000 symulacji.
# Zakończono 20400/1000000 symulacji.
# Zakończono 20500/1000000 symulacji.
# Zakończono 20600/1000000 symulacji.
# Zakończono 20700/1000000 symulacji.
# Zakończono 20800/1000000 symulacji.
# Zakończono 20900/1000000 symulacji.
# Zakończono 21000/1000000 symulacji.
# Zakończono 21100/1000000 symulacji.
# Zakończono 21200/1000000 symulacji.
# Zakończono 21300/1000000 symulacji.
# Zakończono 21400/1000000 symulacji.
# Zakończono 21500/1000000 symulacji.
# Zakończono 21600/1000000 symulacji.
# Zakończono 21700/1000000 symulacji.
# Zakończono 21800/1000000 symulacji.
# Zakończono 21900/1000000 symulacji.
# Zakończono 22000/1000000 symulacji.
# Zakończono 22100/1000000 symulacji.
# Zakończono 22200/1000000 symulacji.
# Zakończono 22300/1000000 symulacji.
# Zakończono 22400/1000000 symulacji.
# Zakończono 22500/1000000 symulacji.
# Zakończono 22600/1000000 symulacji.
# Zakończono 22700/1000000 symulacji.
# Zakończono 22800/1000000 symulacji.
# Zakończono 22900/1000000 symulacji.
# Zakończono 23000/1000000 symulacji.
# Zakończono 23100/1000000 symulacji.
# Zakończono 23200/1000000 symulacji.
# Zakończono 23300/1000000 symulacji.
# Zakończono 23400/1000000 symulacji.
# Zakończono 23500/1000000 symulacji.
# Zakończono 23600/1000000 symulacji.
# Zakończono 23700/1000000 symulacji.
# Zakończono 23800/1000000 symulacji.
# Zakończono 23900/1000000 symulacji.
# Zakończono 24000/1000000 symulacji.
# Zakończono 24100/1000000 symulacji.
# Zakończono 24200/1000000 symulacji.
# Zakończono 24300/1000000 symulacji.
# Zakończono 24400/1000000 symulacji.
# Zakończono 24500/1000000 symulacji.
# Zakończono 24600/1000000 symulacji.
# Zakończono 24700/1000000 symulacji.
# Zakończono 24800/1000000 symulacji.
# Zakończono 24900/1000000 symulacji.
# Zakończono 25000/1000000 symulacji.
# Zakończono 25100/1000000 symulacji.
# Zakończono 25200/1000000 symulacji.
# Zakończono 25300/1000000 symulacji.
# Zakończono 25400/1000000 symulacji.
# Zakończono 25500/1000000 symulacji.
# Zakończono 25600/1000000 symulacji.
# Zakończono 25700/1000000 symulacji.
# Zakończono 25800/1000000 symulacji.
# Zakończono 25900/1000000 symulacji.
# Zakończono 26000/1000000 symulacji.
# Zakończono 26100/1000000 symulacji.
# Zakończono 26200/1000000 symulacji.
# Zakończono 26300/1000000 symulacji.
# Zakończono 26400/1000000 symulacji.
# Zakończono 26500/1000000 symulacji.
# Zakończono 26600/1000000 symulacji.
# Zakończono 26700/1000000 symulacji.
# Zakończono 26800/1000000 symulacji.
# Zakończono 26900/1000000 symulacji.
# Zakończono 27000/1000000 symulacji.
# Zakończono 27100/1000000 symulacji.
# Zakończono 27200/1000000 symulacji.
# Zakończono 27300/1000000 symulacji.
# Zakończono 27400/1000000 symulacji.
# Zakończono 27500/1000000 symulacji.
# Zakończono 27600/1000000 symulacji.
# Zakończono 27700/1000000 symulacji.
# Zakończono 27800/1000000 symulacji.
# Zakończono 27900/1000000 symulacji.
# Zakończono 28000/1000000 symulacji.
# Zakończono 28100/1000000 symulacji.
# Zakończono 28200/1000000 symulacji.
# Zakończono 28300/1000000 symulacji.
# Zakończono 28400/1000000 symulacji.
# Zakończono 28500/1000000 symulacji.
# Zakończono 28600/1000000 symulacji.
# Zakończono 28700/1000000 symulacji.
# Zakończono 28800/1000000 symulacji.
# Zakończono 28900/1000000 symulacji.
# Zakończono 29000/1000000 symulacji.
# Zakończono 29100/1000000 symulacji.
# Zakończono 29200/1000000 symulacji.
# Zakończono 29300/1000000 symulacji.
# Zakończono 29400/1000000 symulacji.
# Zakończono 29500/1000000 symulacji.
# Zakończono 29600/1000000 symulacji.
# Zakończono 29700/1000000 symulacji.
# Zakończono 29800/1000000 symulacji.
# Zakończono 29900/1000000 symulacji.
# Zakończono 30000/1000000 symulacji.
# Zakończono 30100/1000000 symulacji.
# Zakończono 30200/1000000 symulacji.
# Zakończono 30300/1000000 symulacji.
# Zakończono 30400/1000000 symulacji.
# Zakończono 30500/1000000 symulacji.
# Zakończono 30600/1000000 symulacji.
# Zakończono 30700/1000000 symulacji.
# Zakończono 30800/1000000 symulacji.
# Zakończono 30900/1000000 symulacji.
# Zakończono 31000/1000000 symulacji.
# Zakończono 31100/1000000 symulacji.
# Zakończono 31200/1000000 symulacji.
# Zakończono 31300/1000000 symulacji.
# Zakończono 31400/1000000 symulacji.
# Zakończono 31500/1000000 symulacji.
# Zakończono 31600/1000000 symulacji.
# Zakończono 31700/1000000 symulacji.
# Zakończono 31800/1000000 symulacji.
# Zakończono 31900/1000000 symulacji.
# Zakończono 32000/1000000 symulacji.
# Zakończono 32100/1000000 symulacji.
# Zakończono 32200/1000000 symulacji.
# Zakończono 32300/1000000 symulacji.
# Zakończono 32400/1000000 symulacji.
# Zakończono 32500/1000000 symulacji.
# Zakończono 32600/1000000 symulacji.
# Zakończono 32700/1000000 symulacji.
# Zakończono 32800/1000000 symulacji.
# Zakończono 32900/1000000 symulacji.
# Zakończono 33000/1000000 symulacji.
# Zakończono 33100/1000000 symulacji.
# Zakończono 33200/1000000 symulacji.
# Zakończono 33300/1000000 symulacji.
# Zakończono 33400/1000000 symulacji.
# Zakończono 33500/1000000 symulacji.
# Zakończono 33600/1000000 symulacji.
# Zakończono 33700/1000000 symulacji.
# Zakończono 33800/1000000 symulacji.
# Zakończono 33900/1000000 symulacji.
# Zakończono 34000/1000000 symulacji.
# Zakończono 34100/1000000 symulacji.
# Zakończono 34200/1000000 symulacji.
# Zakończono 34300/1000000 symulacji.
# Zakończono 34400/1000000 symulacji.
# Zakończono 34500/1000000 symulacji.
# Zakończono 34600/1000000 symulacji.
# Zakończono 34700/1000000 symulacji.
# Zakończono 34800/1000000 symulacji.
# Zakończono 34900/1000000 symulacji.
# Zakończono 35000/1000000 symulacji.
# Zakończono 35100/1000000 symulacji.
# Zakończono 35200/1000000 symulacji.
# Zakończono 35300/1000000 symulacji.
# Zakończono 35400/1000000 symulacji.
# Zakończono 35500/1000000 symulacji.
# Zakończono 35600/1000000 symulacji.
# Zakończono 35700/1000000 symulacji.
# Zakończono 35800/1000000 symulacji.
# Zakończono 35900/1000000 symulacji.
# Zakończono 36000/1000000 symulacji.
# Zakończono 36100/1000000 symulacji.
# Zakończono 36200/1000000 symulacji.
# Zakończono 36300/1000000 symulacji.
# Zakończono 36400/1000000 symulacji.
# Zakończono 36500/1000000 symulacji.
# Zakończono 36600/1000000 symulacji.
# Zakończono 36700/1000000 symulacji.
# Zakończono 36800/1000000 symulacji.
# Zakończono 36900/1000000 symulacji.
# Zakończono 37000/1000000 symulacji.
# Zakończono 37100/1000000 symulacji.
# Zakończono 37200/1000000 symulacji.
# Zakończono 37300/1000000 symulacji.
# Zakończono 37400/1000000 symulacji.
# Zakończono 37500/1000000 symulacji.
# Zakończono 37600/1000000 symulacji.
# Zakończono 37700/1000000 symulacji.
# Zakończono 37800/1000000 symulacji.
# Zakończono 37900/1000000 symulacji.
# Zakończono 38000/1000000 symulacji.
# Zakończono 38100/1000000 symulacji.
# Zakończono 38200/1000000 symulacji.
# Zakończono 38300/1000000 symulacji.
# Zakończono 38400/1000000 symulacji.
# Zakończono 38500/1000000 symulacji.
# Zakończono 38600/1000000 symulacji.
# Zakończono 38700/1000000 symulacji.
# Zakończono 38800/1000000 symulacji.
# Zakończono 38900/1000000 symulacji.
# Zakończono 39000/1000000 symulacji.
# Zakończono 39100/1000000 symulacji.
# Zakończono 39200/1000000 symulacji.
# Zakończono 39300/1000000 symulacji.
# Zakończono 39400/1000000 symulacji.
# Zakończono 39500/1000000 symulacji.
# Zakończono 39600/1000000 symulacji.
# Zakończono 39700/1000000 symulacji.
# Zakończono 39800/1000000 symulacji.
# Zakończono 39900/1000000 symulacji.
# Zakończono 40000/1000000 symulacji.
# Zakończono 40100/1000000 symulacji.
# Zakończono 40200/1000000 symulacji.
# Zakończono 40300/1000000 symulacji.
# Zakończono 40400/1000000 symulacji.
# Zakończono 40500/1000000 symulacji.
# Zakończono 40600/1000000 symulacji.
# Zakończono 40700/1000000 symulacji.
# Zakończono 40800/1000000 symulacji.
# Zakończono 40900/1000000 symulacji.
# Zakończono 41000/1000000 symulacji.
# Zakończono 41100/1000000 symulacji.
# Zakończono 41200/1000000 symulacji.
# Zakończono 41300/1000000 symulacji.
# Zakończono 41400/1000000 symulacji.
# Zakończono 41500/1000000 symulacji.
# Zakończono 41600/1000000 symulacji.
# Zakończono 41700/1000000 symulacji.
# Zakończono 41800/1000000 symulacji.
# Zakończono 41900/1000000 symulacji.
# Zakończono 42000/1000000 symulacji.
# Zakończono 42100/1000000 symulacji.
# Zakończono 42200/1000000 symulacji.
# Zakończono 42300/1000000 symulacji.
# Zakończono 42400/1000000 symulacji.
# Zakończono 42500/1000000 symulacji.
# Zakończono 42600/1000000 symulacji.
# Zakończono 42700/1000000 symulacji.
# Zakończono 42800/1000000 symulacji.
# Zakończono 42900/1000000 symulacji.
# Zakończono 43000/1000000 symulacji.
# Zakończono 43100/1000000 symulacji.
# Zakończono 43200/1000000 symulacji.
# Zakończono 43300/1000000 symulacji.
# Zakończono 43400/1000000 symulacji.
# Zakończono 43500/1000000 symulacji.
# Zakończono 43600/1000000 symulacji.
# Zakończono 43700/1000000 symulacji.
# Zakończono 43800/1000000 symulacji.
# Zakończono 43900/1000000 symulacji.
# Zakończono 44000/1000000 symulacji.
# Zakończono 44100/1000000 symulacji.
# Zakończono 44200/1000000 symulacji.
# Zakończono 44300/1000000 symulacji.
# Zakończono 44400/1000000 symulacji.
# Zakończono 44500/1000000 symulacji.
# Zakończono 44600/1000000 symulacji.
# Zakończono 44700/1000000 symulacji.
# Zakończono 44800/1000000 symulacji.
# Zakończono 44900/1000000 symulacji.
# Zakończono 45000/1000000 symulacji.
# Zakończono 45100/1000000 symulacji.
# Zakończono 45200/1000000 symulacji.
# Zakończono 45300/1000000 symulacji.
# Zakończono 45400/1000000 symulacji.
# Zakończono 45500/1000000 symulacji.
# Zakończono 45600/1000000 symulacji.
# Zakończono 45700/1000000 symulacji.
# Zakończono 45800/1000000 symulacji.
# Zakończono 45900/1000000 symulacji.
# Zakończono 46000/1000000 symulacji.
# Zakończono 46100/1000000 symulacji.
# Zakończono 46200/1000000 symulacji.
# Zakończono 46300/1000000 symulacji.
# Zakończono 46400/1000000 symulacji.
# Zakończono 46500/1000000 symulacji.
# Zakończono 46600/1000000 symulacji.
# Zakończono 46700/1000000 symulacji.
# Zakończono 46800/1000000 symulacji.
# Zakończono 46900/1000000 symulacji.
# Zakończono 47000/1000000 symulacji.
# Zakończono 47100/1000000 symulacji.
# Zakończono 47200/1000000 symulacji.
# Zakończono 47300/1000000 symulacji.
# Zakończono 47400/1000000 symulacji.
# Zakończono 47500/1000000 symulacji.
# Zakończono 47600/1000000 symulacji.
# Zakończono 47700/1000000 symulacji.
# Zakończono 47800/1000000 symulacji.
# Zakończono 47900/1000000 symulacji.
# Zakończono 48000/1000000 symulacji.
# Zakończono 48100/1000000 symulacji.
# Zakończono 48200/1000000 symulacji.
# Zakończono 48300/1000000 symulacji.
# Zakończono 48400/1000000 symulacji.
# Zakończono 48500/1000000 symulacji.
# Zakończono 48600/1000000 symulacji.
# Zakończono 48700/1000000 symulacji.
# Zakończono 48800/1000000 symulacji.
# Zakończono 48900/1000000 symulacji.
# Zakończono 49000/1000000 symulacji.
# Zakończono 49100/1000000 symulacji.
# Zakończono 49200/1000000 symulacji.
# Zakończono 49300/1000000 symulacji.
# Zakończono 49400/1000000 symulacji.
# Zakończono 49500/1000000 symulacji.
# Zakończono 49600/1000000 symulacji.
# Zakończono 49700/1000000 symulacji.
# Zakończono 49800/1000000 symulacji.
# Zakończono 49900/1000000 symulacji.
# Zakończono 50000/1000000 symulacji.
# Zakończono 50100/1000000 symulacji.
# Zakończono 50200/1000000 symulacji.
# Zakończono 50300/1000000 symulacji.
# Zakończono 50400/1000000 symulacji.
# Zakończono 50500/1000000 symulacji.
# Zakończono 50600/1000000 symulacji.
# Zakończono 50700/1000000 symulacji.
# Zakończono 50800/1000000 symulacji.
# Zakończono 50900/1000000 symulacji.
# Zakończono 51000/1000000 symulacji.
# Zakończono 51100/1000000 symulacji.
# Zakończono 51200/1000000 symulacji.
# Zakończono 51300/1000000 symulacji.
# Zakończono 51400/1000000 symulacji.
# Zakończono 51500/1000000 symulacji.
# Zakończono 51600/1000000 symulacji.
# Zakończono 51700/1000000 symulacji.
# Zakończono 51800/1000000 symulacji.
# Zakończono 51900/1000000 symulacji.
# Zakończono 52000/1000000 symulacji.
# Zakończono 52100/1000000 symulacji.
# Zakończono 52200/1000000 symulacji.
# Zakończono 52300/1000000 symulacji.
# Zakończono 52400/1000000 symulacji.
# Zakończono 52500/1000000 symulacji.
# Zakończono 52600/1000000 symulacji.
# Zakończono 52700/1000000 symulacji.
# Zakończono 52800/1000000 symulacji.
# Zakończono 52900/1000000 symulacji.
# Zakończono 53000/1000000 symulacji.
# Zakończono 53100/1000000 symulacji.
# Zakończono 53200/1000000 symulacji.
# Zakończono 53300/1000000 symulacji.
# Zakończono 53400/1000000 symulacji.
# Zakończono 53500/1000000 symulacji.
# Zakończono 53600/1000000 symulacji.
# Zakończono 53700/1000000 symulacji.
# Zakończono 53800/1000000 symulacji.
# Zakończono 53900/1000000 symulacji.
# Zakończono 54000/1000000 symulacji.
# Zakończono 54100/1000000 symulacji.
# Zakończono 54200/1000000 symulacji.
# Zakończono 54300/1000000 symulacji.
# Zakończono 54400/1000000 symulacji.
# Zakończono 54500/1000000 symulacji.
# Zakończono 54600/1000000 symulacji.
# Zakończono 54700/1000000 symulacji.
# Zakończono 54800/1000000 symulacji.
# Zakończono 54900/1000000 symulacji.
# Zakończono 55000/1000000 symulacji.
# Zakończono 55100/1000000 symulacji.
# Zakończono 55200/1000000 symulacji.
# Zakończono 55300/1000000 symulacji.
# Zakończono 55400/1000000 symulacji.
# Zakończono 55500/1000000 symulacji.
# Zakończono 55600/1000000 symulacji.
# Zakończono 55700/1000000 symulacji.
# Zakończono 55800/1000000 symulacji.
# Zakończono 55900/1000000 symulacji.
# Zakończono 56000/1000000 symulacji.
# Zakończono 56100/1000000 symulacji.
# Zakończono 56200/1000000 symulacji.
# Zakończono 56300/1000000 symulacji.
# Zakończono 56400/1000000 symulacji.
# Zakończono 56500/1000000 symulacji.
# Zakończono 56600/1000000 symulacji.
# Zakończono 56700/1000000 symulacji.
# Zakończono 56800/1000000 symulacji.
# Zakończono 56900/1000000 symulacji.
# Zakończono 57000/1000000 symulacji.
# Zakończono 57100/1000000 symulacji.
# Zakończono 57200/1000000 symulacji.
# Zakończono 57300/1000000 symulacji.
# Zakończono 57400/1000000 symulacji.
# Zakończono 57500/1000000 symulacji.
# Zakończono 57600/1000000 symulacji.
# Zakończono 57700/1000000 symulacji.
# Zakończono 57800/1000000 symulacji.
# Zakończono 57900/1000000 symulacji.
# Zakończono 58000/1000000 symulacji.
# Zakończono 58100/1000000 symulacji.
# Zakończono 58200/1000000 symulacji.
# Zakończono 58300/1000000 symulacji.
# Zakończono 58400/1000000 symulacji.
# Zakończono 58500/1000000 symulacji.
# Zakończono 58600/1000000 symulacji.
# Zakończono 58700/1000000 symulacji.
# Zakończono 58800/1000000 symulacji.
# Zakończono 58900/1000000 symulacji.
# Zakończono 59000/1000000 symulacji.
# Zakończono 59100/1000000 symulacji.
# Zakończono 59200/1000000 symulacji.
# Zakończono 59300/1000000 symulacji.
# Zakończono 59400/1000000 symulacji.
# Zakończono 59500/1000000 symulacji.
# Zakończono 59600/1000000 symulacji.
# Zakończono 59700/1000000 symulacji.
# Zakończono 59800/1000000 symulacji.
# Zakończono 59900/1000000 symulacji.
# Zakończono 60000/1000000 symulacji.
# Zakończono 60100/1000000 symulacji.
# Zakończono 60200/1000000 symulacji.
# Zakończono 60300/1000000 symulacji.
# Zakończono 60400/1000000 symulacji.
# Zakończono 60500/1000000 symulacji.
# Zakończono 60600/1000000 symulacji.
# Zakończono 60700/1000000 symulacji.
# Zakończono 60800/1000000 symulacji.
# Zakończono 60900/1000000 symulacji.
# Zakończono 61000/1000000 symulacji.
# Zakończono 61100/1000000 symulacji.
# Zakończono 61200/1000000 symulacji.
# Zakończono 61300/1000000 symulacji.
# Zakończono 61400/1000000 symulacji.
# Zakończono 61500/1000000 symulacji.
# Zakończono 61600/1000000 symulacji.
# Zakończono 61700/1000000 symulacji.
# Zakończono 61800/1000000 symulacji.
# Zakończono 61900/1000000 symulacji.
# Zakończono 62000/1000000 symulacji.
# Zakończono 62100/1000000 symulacji.
# Zakończono 62200/1000000 symulacji.
# Zakończono 62300/1000000 symulacji.
# Zakończono 62400/1000000 symulacji.
# Zakończono 62500/1000000 symulacji.
# Zakończono 62600/1000000 symulacji.
# Zakończono 62700/1000000 symulacji.
# Zakończono 62800/1000000 symulacji.
# Zakończono 62900/1000000 symulacji.
# Zakończono 63000/1000000 symulacji.
# Zakończono 63100/1000000 symulacji.
# Zakończono 63200/1000000 symulacji.
# Zakończono 63300/1000000 symulacji.
# Zakończono 63400/1000000 symulacji.
# Zakończono 63500/1000000 symulacji.
# Zakończono 63600/1000000 symulacji.
# Zakończono 63700/1000000 symulacji.
# Zakończono 63800/1000000 symulacji.
# Zakończono 63900/1000000 symulacji.
# Zakończono 64000/1000000 symulacji.
# Zakończono 64100/1000000 symulacji.
# Zakończono 64200/1000000 symulacji.
# Zakończono 64300/1000000 symulacji.
# Zakończono 64400/1000000 symulacji.
# Zakończono 64500/1000000 symulacji.
# Zakończono 64600/1000000 symulacji.
# Zakończono 64700/1000000 symulacji.
# Zakończono 64800/1000000 symulacji.
# Zakończono 64900/1000000 symulacji.
# Zakończono 65000/1000000 symulacji.
# Zakończono 65100/1000000 symulacji.
# Zakończono 65200/1000000 symulacji.
# Zakończono 65300/1000000 symulacji.
# Zakończono 65400/1000000 symulacji.
# Zakończono 65500/1000000 symulacji.
# Zakończono 65600/1000000 symulacji.
# Zakończono 65700/1000000 symulacji.
# Zakończono 65800/1000000 symulacji.
# Zakończono 65900/1000000 symulacji.
# Zakończono 66000/1000000 symulacji.
# Zakończono 66100/1000000 symulacji.
# Zakończono 66200/1000000 symulacji.
# Zakończono 66300/1000000 symulacji.
# Zakończono 66400/1000000 symulacji.
# Zakończono 66500/1000000 symulacji.
# Zakończono 66600/1000000 symulacji.
# Zakończono 66700/1000000 symulacji.
# Zakończono 66800/1000000 symulacji.
# Zakończono 66900/1000000 symulacji.
# Zakończono 67000/1000000 symulacji.
# Zakończono 67100/1000000 symulacji.
# Zakończono 67200/1000000 symulacji.
# Zakończono 67300/1000000 symulacji.
# Zakończono 67400/1000000 symulacji.
# Zakończono 67500/1000000 symulacji.
# Zakończono 67600/1000000 symulacji.
# Zakończono 67700/1000000 symulacji.
# Zakończono 67800/1000000 symulacji.
# Zakończono 67900/1000000 symulacji.
# Zakończono 68000/1000000 symulacji.
# Zakończono 68100/1000000 symulacji.
# Zakończono 68200/1000000 symulacji.
# Zakończono 68300/1000000 symulacji.
# Zakończono 68400/1000000 symulacji.
# Zakończono 68500/1000000 symulacji.
# Zakończono 68600/1000000 symulacji.
# Zakończono 68700/1000000 symulacji.
# Zakończono 68800/1000000 symulacji.
# Zakończono 68900/1000000 symulacji.
# Zakończono 69000/1000000 symulacji.
# Zakończono 69100/1000000 symulacji.
# Zakończono 69200/1000000 symulacji.
# Zakończono 69300/1000000 symulacji.
# Zakończono 69400/1000000 symulacji.
# Zakończono 69500/1000000 symulacji.
# Zakończono 69600/1000000 symulacji.
# Zakończono 69700/1000000 symulacji.
# Zakończono 69800/1000000 symulacji.
# Zakończono 69900/1000000 symulacji.
# Zakończono 70000/1000000 symulacji.
# Zakończono 70100/1000000 symulacji.
# Zakończono 70200/1000000 symulacji.
# Zakończono 70300/1000000 symulacji.
# Zakończono 70400/1000000 symulacji.
# Zakończono 70500/1000000 symulacji.
# Zakończono 70600/1000000 symulacji.
# Zakończono 70700/1000000 symulacji.
# Zakończono 70800/1000000 symulacji.
# Zakończono 70900/1000000 symulacji.
# Zakończono 71000/1000000 symulacji.
# Zakończono 71100/1000000 symulacji.
# Zakończono 71200/1000000 symulacji.
# Zakończono 71300/1000000 symulacji.
# Zakończono 71400/1000000 symulacji.
# Zakończono 71500/1000000 symulacji.
# Zakończono 71600/1000000 symulacji.
# Zakończono 71700/1000000 symulacji.
# Zakończono 71800/1000000 symulacji.
# Zakończono 71900/1000000 symulacji.
# Zakończono 72000/1000000 symulacji.
# Zakończono 72100/1000000 symulacji.
# Zakończono 72200/1000000 symulacji.
# Zakończono 72300/1000000 symulacji.
# Zakończono 72400/1000000 symulacji.
# Zakończono 72500/1000000 symulacji.
# Zakończono 72600/1000000 symulacji.
# Zakończono 72700/1000000 symulacji.
# Zakończono 72800/1000000 symulacji.
# Zakończono 72900/1000000 symulacji.
# Zakończono 73000/1000000 symulacji.
# Zakończono 73100/1000000 symulacji.
# Zakończono 73200/1000000 symulacji.
# Zakończono 73300/1000000 symulacji.
# Zakończono 73400/1000000 symulacji.
# Zakończono 73500/1000000 symulacji.
# Zakończono 73600/1000000 symulacji.
# Zakończono 73700/1000000 symulacji.
# Zakończono 73800/1000000 symulacji.
# Zakończono 73900/1000000 symulacji.
# Zakończono 74000/1000000 symulacji.
# Zakończono 74100/1000000 symulacji.
# Zakończono 74200/1000000 symulacji.
# Zakończono 74300/1000000 symulacji.
# Zakończono 74400/1000000 symulacji.
# Zakończono 74500/1000000 symulacji.
# Zakończono 74600/1000000 symulacji.
# Zakończono 74700/1000000 symulacji.
# Zakończono 74800/1000000 symulacji.
# Zakończono 74900/1000000 symulacji.
# Zakończono 75000/1000000 symulacji.
# Zakończono 75100/1000000 symulacji.
# Zakończono 75200/1000000 symulacji.
# Zakończono 75300/1000000 symulacji.
# Zakończono 75400/1000000 symulacji.
# Zakończono 75500/1000000 symulacji.
# Zakończono 75600/1000000 symulacji.
# Zakończono 75700/1000000 symulacji.
# Zakończono 75800/1000000 symulacji.
# Zakończono 75900/1000000 symulacji.
# Zakończono 76000/1000000 symulacji.
# Zakończono 76100/1000000 symulacji.
# Zakończono 76200/1000000 symulacji.
# Zakończono 76300/1000000 symulacji.
# Zakończono 76400/1000000 symulacji.
# Zakończono 76500/1000000 symulacji.
# Zakończono 76600/1000000 symulacji.
# Zakończono 76700/1000000 symulacji.
# Zakończono 76800/1000000 symulacji.
# Zakończono 76900/1000000 symulacji.
# Zakończono 77000/1000000 symulacji.
# Zakończono 77100/1000000 symulacji.
# Zakończono 77200/1000000 symulacji.
# Zakończono 77300/1000000 symulacji.
# Zakończono 77400/1000000 symulacji.
# Zakończono 77500/1000000 symulacji.
# Zakończono 77600/1000000 symulacji.
# Zakończono 77700/1000000 symulacji.
# Zakończono 77800/1000000 symulacji.
# Zakończono 77900/1000000 symulacji.
# Zakończono 78000/1000000 symulacji.
# Zakończono 78100/1000000 symulacji.
# Zakończono 78200/1000000 symulacji.
# Zakończono 78300/1000000 symulacji.
# Zakończono 78400/1000000 symulacji.
# Zakończono 78500/1000000 symulacji.
# Zakończono 78600/1000000 symulacji.
# Zakończono 78700/1000000 symulacji.
# Zakończono 78800/1000000 symulacji.
# Zakończono 78900/1000000 symulacji.
# Zakończono 79000/1000000 symulacji.
# Zakończono 79100/1000000 symulacji.
# Zakończono 79200/1000000 symulacji.
# Zakończono 79300/1000000 symulacji.
# Zakończono 79400/1000000 symulacji.
# Zakończono 79500/1000000 symulacji.
# Zakończono 79600/1000000 symulacji.
# Zakończono 79700/1000000 symulacji.
# Zakończono 79800/1000000 symulacji.
# Zakończono 79900/1000000 symulacji.
# Zakończono 80000/1000000 symulacji.
# Zakończono 80100/1000000 symulacji.
# Zakończono 80200/1000000 symulacji.
# Zakończono 80300/1000000 symulacji.
# Zakończono 80400/1000000 symulacji.
# Zakończono 80500/1000000 symulacji.
# Zakończono 80600/1000000 symulacji.
# Zakończono 80700/1000000 symulacji.
# Zakończono 80800/1000000 symulacji.
# Zakończono 80900/1000000 symulacji.
# Zakończono 81000/1000000 symulacji.
# Zakończono 81100/1000000 symulacji.
# Zakończono 81200/1000000 symulacji.
# Zakończono 81300/1000000 symulacji.
# Zakończono 81400/1000000 symulacji.
# Zakończono 81500/1000000 symulacji.
# Zakończono 81600/1000000 symulacji.
# Zakończono 81700/1000000 symulacji.
# Zakończono 81800/1000000 symulacji.
# Zakończono 81900/1000000 symulacji.
# Zakończono 82000/1000000 symulacji.
# Zakończono 82100/1000000 symulacji.
# Zakończono 82200/1000000 symulacji.
# Zakończono 82300/1000000 symulacji.
# Zakończono 82400/1000000 symulacji.
# Zakończono 82500/1000000 symulacji.
# Zakończono 82600/1000000 symulacji.
# Zakończono 82700/1000000 symulacji.
# Zakończono 82800/1000000 symulacji.
# Zakończono 82900/1000000 symulacji.
# Zakończono 83000/1000000 symulacji.
# Zakończono 83100/1000000 symulacji.
# Zakończono 83200/1000000 symulacji.
# Zakończono 83300/1000000 symulacji.
# Zakończono 83400/1000000 symulacji.
# Zakończono 83500/1000000 symulacji.
# Zakończono 83600/1000000 symulacji.
# Zakończono 83700/1000000 symulacji.
# Zakończono 83800/1000000 symulacji.
# Zakończono 83900/1000000 symulacji.
# Zakończono 84000/1000000 symulacji.
# Zakończono 84100/1000000 symulacji.
# Zakończono 84200/1000000 symulacji.
# Zakończono 84300/1000000 symulacji.
# Zakończono 84400/1000000 symulacji.
# Zakończono 84500/1000000 symulacji.
# Zakończono 84600/1000000 symulacji.
# Zakończono 84700/1000000 symulacji.
# Zakończono 84800/1000000 symulacji.
# Zakończono 84900/1000000 symulacji.
# Zakończono 85000/1000000 symulacji.
# Zakończono 85100/1000000 symulacji.
# Zakończono 85200/1000000 symulacji.
# Zakończono 85300/1000000 symulacji.
# Zakończono 85400/1000000 symulacji.
# Zakończono 85500/1000000 symulacji.
# Zakończono 85600/1000000 symulacji.
# Zakończono 85700/1000000 symulacji.
# Zakończono 85800/1000000 symulacji.
# Zakończono 85900/1000000 symulacji.
# Zakończono 86000/1000000 symulacji.
# Zakończono 86100/1000000 symulacji.
# Zakończono 86200/1000000 symulacji.
# Zakończono 86300/1000000 symulacji.
# Zakończono 86400/1000000 symulacji.
# Zakończono 86500/1000000 symulacji.
# Zakończono 86600/1000000 symulacji.
# Zakończono 86700/1000000 symulacji.
# Zakończono 86800/1000000 symulacji.
# Zakończono 86900/1000000 symulacji.
# Zakończono 87000/1000000 symulacji.
# Zakończono 87100/1000000 symulacji.
# Zakończono 87200/1000000 symulacji.
# Zakończono 87300/1000000 symulacji.
# Zakończono 87400/1000000 symulacji.
# Zakończono 87500/1000000 symulacji.
# Zakończono 87600/1000000 symulacji.
# Zakończono 87700/1000000 symulacji.
# Zakończono 87800/1000000 symulacji.
# Zakończono 87900/1000000 symulacji.
# Zakończono 88000/1000000 symulacji.
# Zakończono 88100/1000000 symulacji.
# Zakończono 88200/1000000 symulacji.
# Zakończono 88300/1000000 symulacji.
# Zakończono 88400/1000000 symulacji.
# Zakończono 88500/1000000 symulacji.
# Zakończono 88600/1000000 symulacji.
# Zakończono 88700/1000000 symulacji.
# Zakończono 88800/1000000 symulacji.
# Zakończono 88900/1000000 symulacji.
# Zakończono 89000/1000000 symulacji.
# Zakończono 89100/1000000 symulacji.
# Zakończono 89200/1000000 symulacji.
# Zakończono 89300/1000000 symulacji.
# Zakończono 89400/1000000 symulacji.
# Zakończono 89500/1000000 symulacji.
# Zakończono 89600/1000000 symulacji.
# Zakończono 89700/1000000 symulacji.
# Zakończono 89800/1000000 symulacji.
# Zakończono 89900/1000000 symulacji.
# Zakończono 90000/1000000 symulacji.
# Zakończono 90100/1000000 symulacji.
# Zakończono 90200/1000000 symulacji.
# Zakończono 90300/1000000 symulacji.
# Zakończono 90400/1000000 symulacji.
# Zakończono 90500/1000000 symulacji.
# Zakończono 90600/1000000 symulacji.
# Zakończono 90700/1000000 symulacji.
# Zakończono 90800/1000000 symulacji.
# Zakończono 90900/1000000 symulacji.
# Zakończono 91000/1000000 symulacji.
# Zakończono 91100/1000000 symulacji.
# Zakończono 91200/1000000 symulacji.
# Zakończono 91300/1000000 symulacji.
# Zakończono 91400/1000000 symulacji.
# Zakończono 91500/1000000 symulacji.
# Zakończono 91600/1000000 symulacji.
# Zakończono 91700/1000000 symulacji.
# Zakończono 91800/1000000 symulacji.
# Zakończono 91900/1000000 symulacji.
# Zakończono 92000/1000000 symulacji.
# Zakończono 92100/1000000 symulacji.
# Zakończono 92200/1000000 symulacji.
# Zakończono 92300/1000000 symulacji.
# Zakończono 92400/1000000 symulacji.
# Zakończono 92500/1000000 symulacji.
# Zakończono 92600/1000000 symulacji.
# Zakończono 92700/1000000 symulacji.
# Zakończono 92800/1000000 symulacji.
# Zakończono 92900/1000000 symulacji.
# Zakończono 93000/1000000 symulacji.
# Zakończono 93100/1000000 symulacji.
# Zakończono 93200/1000000 symulacji.
# Zakończono 93300/1000000 symulacji.
# Zakończono 93400/1000000 symulacji.
# Zakończono 93500/1000000 symulacji.
# Zakończono 93600/1000000 symulacji.
# Zakończono 93700/1000000 symulacji.
# Zakończono 93800/1000000 symulacji.
# Zakończono 93900/1000000 symulacji.
# Zakończono 94000/1000000 symulacji.
# Zakończono 94100/1000000 symulacji.
# Zakończono 94200/1000000 symulacji.
# Zakończono 94300/1000000 symulacji.
# Zakończono 94400/1000000 symulacji.
# Zakończono 94500/1000000 symulacji.
# Zakończono 94600/1000000 symulacji.
# Zakończono 94700/1000000 symulacji.
# Zakończono 94800/1000000 symulacji.
# Zakończono 94900/1000000 symulacji.
# Zakończono 95000/1000000 symulacji.
# Zakończono 95100/1000000 symulacji.
# Zakończono 95200/1000000 symulacji.
# Zakończono 95300/1000000 symulacji.
# Zakończono 95400/1000000 symulacji.
# Zakończono 95500/1000000 symulacji.
# Zakończono 95600/1000000 symulacji.
# Zakończono 95700/1000000 symulacji.
# Zakończono 95800/1000000 symulacji.
# Zakończono 95900/1000000 symulacji.
# Zakończono 96000/1000000 symulacji.
# Zakończono 96100/1000000 symulacji.
# Zakończono 96200/1000000 symulacji.
# Zakończono 96300/1000000 symulacji.
# Zakończono 96400/1000000 symulacji.
# Zakończono 96500/1000000 symulacji.
# Zakończono 96600/1000000 symulacji.
# Zakończono 96700/1000000 symulacji.
# Zakończono 96800/1000000 symulacji.
# Zakończono 96900/1000000 symulacji.
# Zakończono 97000/1000000 symulacji.
# Zakończono 97100/1000000 symulacji.
# Zakończono 97200/1000000 symulacji.
# Zakończono 97300/1000000 symulacji.
# Zakończono 97400/1000000 symulacji.
# Zakończono 97500/1000000 symulacji.
# Zakończono 97600/1000000 symulacji.
# Zakończono 97700/1000000 symulacji.
# Zakończono 97800/1000000 symulacji.
# Zakończono 97900/1000000 symulacji.
# Zakończono 98000/1000000 symulacji.
# Zakończono 98100/1000000 symulacji.
# Zakończono 98200/1000000 symulacji.
# Zakończono 98300/1000000 symulacji.
# Zakończono 98400/1000000 symulacji.
# Zakończono 98500/1000000 symulacji.
# Zakończono 98600/1000000 symulacji.
# Zakończono 98700/1000000 symulacji.
# Zakończono 98800/1000000 symulacji.
# Zakończono 98900/1000000 symulacji.
# Zakończono 99000/1000000 symulacji.
# Zakończono 99100/1000000 symulacji.
# Zakończono 99200/1000000 symulacji.
# Zakończono 99300/1000000 symulacji.
# Zakończono 99400/1000000 symulacji.
# Zakończono 99500/1000000 symulacji.
# Zakończono 99600/1000000 symulacji.
# Zakończono 99700/1000000 symulacji.
# Zakończono 99800/1000000 symulacji.
# Zakończono 99900/1000000 symulacji.
# Zakończono 100000/1000000 symulacji.
# Zakończono 100100/1000000 symulacji.
# Zakończono 100200/1000000 symulacji.
# Zakończono 100300/1000000 symulacji.
# Zakończono 100400/1000000 symulacji.
# Zakończono 100500/1000000 symulacji.
# Zakończono 100600/1000000 symulacji.
# Zakończono 100700/1000000 symulacji.
# Zakończono 100800/1000000 symulacji.
# Zakończono 100900/1000000 symulacji.
# Zakończono 101000/1000000 symulacji.
# Zakończono 101100/1000000 symulacji.
# Zakończono 101200/1000000 symulacji.
# Zakończono 101300/1000000 symulacji.
# Zakończono 101400/1000000 symulacji.
# Zakończono 101500/1000000 symulacji.
# Zakończono 101600/1000000 symulacji.
# Zakończono 101700/1000000 symulacji.
# Zakończono 101800/1000000 symulacji.
# Zakończono 101900/1000000 symulacji.
# Zakończono 102000/1000000 symulacji.
# Zakończono 102100/1000000 symulacji.
# Zakończono 102200/1000000 symulacji.
# Zakończono 102300/1000000 symulacji.
# Zakończono 102400/1000000 symulacji.
# Zakończono 102500/1000000 symulacji.
# Zakończono 102600/1000000 symulacji.
# Zakończono 102700/1000000 symulacji.
# Zakończono 102800/1000000 symulacji.
# Zakończono 102900/1000000 symulacji.
# Zakończono 103000/1000000 symulacji.
# Zakończono 103100/1000000 symulacji.
# Zakończono 103200/1000000 symulacji.
# Zakończono 103300/1000000 symulacji.
# Zakończono 103400/1000000 symulacji.
# Zakończono 103500/1000000 symulacji.
# Zakończono 103600/1000000 symulacji.
# Zakończono 103700/1000000 symulacji.
# Zakończono 103800/1000000 symulacji.
# Zakończono 103900/1000000 symulacji.
# Zakończono 104000/1000000 symulacji.
# Zakończono 104100/1000000 symulacji.
# Zakończono 104200/1000000 symulacji.
# Zakończono 104300/1000000 symulacji.
# Zakończono 104400/1000000 symulacji.
# Zakończono 104500/1000000 symulacji.
# Zakończono 104600/1000000 symulacji.
# Zakończono 104700/1000000 symulacji.
# Zakończono 104800/1000000 symulacji.
# Zakończono 104900/1000000 symulacji.
# Zakończono 105000/1000000 symulacji.
# Zakończono 105100/1000000 symulacji.
# Zakończono 105200/1000000 symulacji.
# Zakończono 105300/1000000 symulacji.
# Zakończono 105400/1000000 symulacji.
# Zakończono 105500/1000000 symulacji.
# Zakończono 105600/1000000 symulacji.
# Zakończono 105700/1000000 symulacji.
# Zakończono 105800/1000000 symulacji.
# Zakończono 105900/1000000 symulacji.
# Zakończono 106000/1000000 symulacji.
# Zakończono 106100/1000000 symulacji.
# Zakończono 106200/1000000 symulacji.
# Zakończono 106300/1000000 symulacji.
# Zakończono 106400/1000000 symulacji.
# Zakończono 106500/1000000 symulacji.
# Zakończono 106600/1000000 symulacji.
# Zakończono 106700/1000000 symulacji.
# Zakończono 106800/1000000 symulacji.
# Zakończono 106900/1000000 symulacji.
# Zakończono 107000/1000000 symulacji.
# Zakończono 107100/1000000 symulacji.
# Zakończono 107200/1000000 symulacji.
# Zakończono 107300/1000000 symulacji.
# Zakończono 107400/1000000 symulacji.
# Zakończono 107500/1000000 symulacji.
# Zakończono 107600/1000000 symulacji.
# Zakończono 107700/1000000 symulacji.
# Zakończono 107800/1000000 symulacji.
# Zakończono 107900/1000000 symulacji.
# Zakończono 108000/1000000 symulacji.
# Zakończono 108100/1000000 symulacji.
# Zakończono 108200/1000000 symulacji.
# Zakończono 108300/1000000 symulacji.
# Zakończono 108400/1000000 symulacji.
# Zakończono 108500/1000000 symulacji.
# Zakończono 108600/1000000 symulacji.
# Zakończono 108700/1000000 symulacji.
# Zakończono 108800/1000000 symulacji.
# Zakończono 108900/1000000 symulacji.
# Zakończono 109000/1000000 symulacji.
# Zakończono 109100/1000000 symulacji.
# Zakończono 109200/1000000 symulacji.
# Zakończono 109300/1000000 symulacji.
# Zakończono 109400/1000000 symulacji.
# Zakończono 109500/1000000 symulacji.
# Zakończono 109600/1000000 symulacji.
# Zakończono 109700/1000000 symulacji.
# Zakończono 109800/1000000 symulacji.
# Zakończono 109900/1000000 symulacji.
# Zakończono 110000/1000000 symulacji.
# Zakończono 110100/1000000 symulacji.
# Zakończono 110200/1000000 symulacji.
# Zakończono 110300/1000000 symulacji.
# Zakończono 110400/1000000 symulacji.
# Zakończono 110500/1000000 symulacji.
# Zakończono 110600/1000000 symulacji.
# Zakończono 110700/1000000 symulacji.
# Zakończono 110800/1000000 symulacji.
# Zakończono 110900/1000000 symulacji.
# Zakończono 111000/1000000 symulacji.
# Zakończono 111100/1000000 symulacji.
# Zakończono 111200/1000000 symulacji.
# Zakończono 111300/1000000 symulacji.
# Zakończono 111400/1000000 symulacji.
# Zakończono 111500/1000000 symulacji.
# Zakończono 111600/1000000 symulacji.
# Zakończono 111700/1000000 symulacji.
# Zakończono 111800/1000000 symulacji.
# Zakończono 111900/1000000 symulacji.
# Zakończono 112000/1000000 symulacji.
# Zakończono 112100/1000000 symulacji.
# Zakończono 112200/1000000 symulacji.
# Zakończono 112300/1000000 symulacji.
# Zakończono 112400/1000000 symulacji.
# Zakończono 112500/1000000 symulacji.
# Zakończono 112600/1000000 symulacji.
# Zakończono 112700/1000000 symulacji.
# Zakończono 112800/1000000 symulacji.
# Zakończono 112900/1000000 symulacji.
# Zakończono 113000/1000000 symulacji.
# Zakończono 113100/1000000 symulacji.
# Zakończono 113200/1000000 symulacji.
# Zakończono 113300/1000000 symulacji.
# Zakończono 113400/1000000 symulacji.
# Zakończono 113500/1000000 symulacji.
# Zakończono 113600/1000000 symulacji.
# Zakończono 113700/1000000 symulacji.
# Zakończono 113800/1000000 symulacji.
# Zakończono 113900/1000000 symulacji.
# Zakończono 114000/1000000 symulacji.
# Zakończono 114100/1000000 symulacji.
# Zakończono 114200/1000000 symulacji.
# Zakończono 114300/1000000 symulacji.
# Zakończono 114400/1000000 symulacji.
# Zakończono 114500/1000000 symulacji.
# Zakończono 114600/1000000 symulacji.
# Zakończono 114700/1000000 symulacji.
# Zakończono 114800/1000000 symulacji.
# Zakończono 114900/1000000 symulacji.
# Zakończono 115000/1000000 symulacji.
# Zakończono 115100/1000000 symulacji.
# Zakończono 115200/1000000 symulacji.
# Zakończono 115300/1000000 symulacji.
# Zakończono 115400/1000000 symulacji.
# Zakończono 115500/1000000 symulacji.
# Zakończono 115600/1000000 symulacji.
# Zakończono 115700/1000000 symulacji.
# Zakończono 115800/1000000 symulacji.
# Zakończono 115900/1000000 symulacji.
# Zakończono 116000/1000000 symulacji.
# Zakończono 116100/1000000 symulacji.
# Zakończono 116200/1000000 symulacji.
# Zakończono 116300/1000000 symulacji.
# Zakończono 116400/1000000 symulacji.
# Zakończono 116500/1000000 symulacji.
# Zakończono 116600/1000000 symulacji.
# Zakończono 116700/1000000 symulacji.
# Zakończono 116800/1000000 symulacji.
# Zakończono 116900/1000000 symulacji.
# Zakończono 117000/1000000 symulacji.
# Zakończono 117100/1000000 symulacji.
# Zakończono 117200/1000000 symulacji.
# Zakończono 117300/1000000 symulacji.
# Zakończono 117400/1000000 symulacji.
# Zakończono 117500/1000000 symulacji.
# Zakończono 117600/1000000 symulacji.
# Zakończono 117700/1000000 symulacji.
# Zakończono 117800/1000000 symulacji.
# Zakończono 117900/1000000 symulacji.
# Zakończono 118000/1000000 symulacji.
# Zakończono 118100/1000000 symulacji.
# Zakończono 118200/1000000 symulacji.
# Zakończono 118300/1000000 symulacji.
# Zakończono 118400/1000000 symulacji.
# Zakończono 118500/1000000 symulacji.
# Zakończono 118600/1000000 symulacji.
# Zakończono 118700/1000000 symulacji.
# Zakończono 118800/1000000 symulacji.
# Zakończono 118900/1000000 symulacji.
# Zakończono 119000/1000000 symulacji.
# Zakończono 119100/1000000 symulacji.
# Zakończono 119200/1000000 symulacji.
# Zakończono 119300/1000000 symulacji.
# Zakończono 119400/1000000 symulacji.
# Zakończono 119500/1000000 symulacji.
# Zakończono 119600/1000000 symulacji.
# Zakończono 119700/1000000 symulacji.
# Zakończono 119800/1000000 symulacji.
# Zakończono 119900/1000000 symulacji.
# Zakończono 120000/1000000 symulacji.
# Zakończono 120100/1000000 symulacji.
# Zakończono 120200/1000000 symulacji.
# Zakończono 120300/1000000 symulacji.
# Zakończono 120400/1000000 symulacji.
# Zakończono 120500/1000000 symulacji.
# Zakończono 120600/1000000 symulacji.
# Zakończono 120700/1000000 symulacji.
# Zakończono 120800/1000000 symulacji.
# Zakończono 120900/1000000 symulacji.
# Zakończono 121000/1000000 symulacji.
# Zakończono 121100/1000000 symulacji.
# Zakończono 121200/1000000 symulacji.
# Zakończono 121300/1000000 symulacji.
# Zakończono 121400/1000000 symulacji.
# Zakończono 121500/1000000 symulacji.
# Zakończono 121600/1000000 symulacji.
# Zakończono 121700/1000000 symulacji.
# Zakończono 121800/1000000 symulacji.
# Zakończono 121900/1000000 symulacji.
# Zakończono 122000/1000000 symulacji.
# Zakończono 122100/1000000 symulacji.
# Zakończono 122200/1000000 symulacji.
# Zakończono 122300/1000000 symulacji.
# Zakończono 122400/1000000 symulacji.
# Zakończono 122500/1000000 symulacji.
# Zakończono 122600/1000000 symulacji.
# Zakończono 122700/1000000 symulacji.
# Zakończono 122800/1000000 symulacji.
# Zakończono 122900/1000000 symulacji.
# Zakończono 123000/1000000 symulacji.
# Zakończono 123100/1000000 symulacji.
# Zakończono 123200/1000000 symulacji.
# Zakończono 123300/1000000 symulacji.
# Zakończono 123400/1000000 symulacji.
# Zakończono 123500/1000000 symulacji.
# Zakończono 123600/1000000 symulacji.
# Zakończono 123700/1000000 symulacji.
# Zakończono 123800/1000000 symulacji.
# Zakończono 123900/1000000 symulacji.
# Zakończono 124000/1000000 symulacji.
# Zakończono 124100/1000000 symulacji.
# Zakończono 124200/1000000 symulacji.
# Zakończono 124300/1000000 symulacji.
# Zakończono 124400/1000000 symulacji.
# Zakończono 124500/1000000 symulacji.
# Zakończono 124600/1000000 symulacji.
# Zakończono 124700/1000000 symulacji.
# Zakończono 124800/1000000 symulacji.
# Zakończono 124900/1000000 symulacji.
# Zakończono 125000/1000000 symulacji.
# Zakończono 125100/1000000 symulacji.
# Zakończono 125200/1000000 symulacji.
# Zakończono 125300/1000000 symulacji.
# Zakończono 125400/1000000 symulacji.
# Zakończono 125500/1000000 symulacji.
# Zakończono 125600/1000000 symulacji.
# Zakończono 125700/1000000 symulacji.
# Zakończono 125800/1000000 symulacji.
# Zakończono 125900/1000000 symulacji.
# Zakończono 126000/1000000 symulacji.
# Zakończono 126100/1000000 symulacji.
# Zakończono 126200/1000000 symulacji.
# Zakończono 126300/1000000 symulacji.
# Zakończono 126400/1000000 symulacji.
# Zakończono 126500/1000000 symulacji.
# Zakończono 126600/1000000 symulacji.
# Zakończono 126700/1000000 symulacji.
# Zakończono 126800/1000000 symulacji.
# Zakończono 126900/1000000 symulacji.
# Zakończono 127000/1000000 symulacji.
# Zakończono 127100/1000000 symulacji.
# Zakończono 127200/1000000 symulacji.
# Zakończono 127300/1000000 symulacji.
# Zakończono 127400/1000000 symulacji.
# Zakończono 127500/1000000 symulacji.
# Zakończono 127600/1000000 symulacji.
# Zakończono 127700/1000000 symulacji.
# Zakończono 127800/1000000 symulacji.
# Zakończono 127900/1000000 symulacji.
# Zakończono 128000/1000000 symulacji.
# Zakończono 128100/1000000 symulacji.
# Zakończono 128200/1000000 symulacji.
# Zakończono 128300/1000000 symulacji.
# Zakończono 128400/1000000 symulacji.
# Zakończono 128500/1000000 symulacji.
# Zakończono 128600/1000000 symulacji.
# Zakończono 128700/1000000 symulacji.
# Zakończono 128800/1000000 symulacji.
# Zakończono 128900/1000000 symulacji.
# Zakończono 129000/1000000 symulacji.
# Zakończono 129100/1000000 symulacji.
# Zakończono 129200/1000000 symulacji.
# Zakończono 129300/1000000 symulacji.
# Zakończono 129400/1000000 symulacji.
# Zakończono 129500/1000000 symulacji.
# Zakończono 129600/1000000 symulacji.
# Zakończono 129700/1000000 symulacji.
# Zakończono 129800/1000000 symulacji.
# Zakończono 129900/1000000 symulacji.
# Zakończono 130000/1000000 symulacji.
# Zakończono 130100/1000000 symulacji.
# Zakończono 130200/1000000 symulacji.
# Zakończono 130300/1000000 symulacji.
# Zakończono 130400/1000000 symulacji.
# Zakończono 130500/1000000 symulacji.
# Zakończono 130600/1000000 symulacji.
# Zakończono 130700/1000000 symulacji.
# Zakończono 130800/1000000 symulacji.
# Zakończono 130900/1000000 symulacji.
# Zakończono 131000/1000000 symulacji.
# Zakończono 131100/1000000 symulacji.
# Zakończono 131200/1000000 symulacji.
# Zakończono 131300/1000000 symulacji.
# Zakończono 131400/1000000 symulacji.
# Zakończono 131500/1000000 symulacji.
# Zakończono 131600/1000000 symulacji.
# Zakończono 131700/1000000 symulacji.
# Zakończono 131800/1000000 symulacji.
# Zakończono 131900/1000000 symulacji.
# Zakończono 132000/1000000 symulacji.
# Zakończono 132100/1000000 symulacji.
# Zakończono 132200/1000000 symulacji.
# Zakończono 132300/1000000 symulacji.
# Zakończono 132400/1000000 symulacji.
# Zakończono 132500/1000000 symulacji.
# ...
# Zakończono 958800/1000000 symulacji.
# Zakończono 958900/1000000 symulacji.
# Zakończono 959000/1000000 symulacji.
# Zakończono 959100/1000000 symulacji.
# Zakończono 959200/1000000 symulacji.
# Zakończono 959300/1000000 symulacji.
# Zakończono 959400/1000000 symulacji.
# Zakończono 959500/1000000 symulacji.
# Zakończono 959600/1000000 symulacji.
# Zakończono 959700/1000000 symulacji.
# Zakończono 959800/1000000 symulacji.
# Zakończono 959900/1000000 symulacji.
# Zakończono 960000/1000000 symulacji.
# Zakończono 960100/1000000 symulacji.
# Zakończono 960200/1000000 symulacji.
# Zakończono 960300/1000000 symulacji.
# Zakończono 960400/1000000 symulacji.
# Zakończono 960500/1000000 symulacji.
# Zakończono 960600/1000000 symulacji.
# Zakończono 960700/1000000 symulacji.
# Zakończono 960800/1000000 symulacji.
# Zakończono 960900/1000000 symulacji.
# Zakończono 961000/1000000 symulacji.
# Zakończono 961100/1000000 symulacji.
# Zakończono 961200/1000000 symulacji.
# Zakończono 961300/1000000 symulacji.
# Zakończono 961400/1000000 symulacji.
# Zakończono 961500/1000000 symulacji.
# Zakończono 961600/1000000 symulacji.
# Zakończono 961700/1000000 symulacji.
# Zakończono 961800/1000000 symulacji.
# Zakończono 961900/1000000 symulacji.
# Zakończono 962000/1000000 symulacji.
# Zakończono 962100/1000000 symulacji.
# Zakończono 962200/1000000 symulacji.
# Zakończono 962300/1000000 symulacji.
# Zakończono 962400/1000000 symulacji.
# Zakończono 962500/1000000 symulacji.
# Zakończono 962600/1000000 symulacji.
# Zakończono 962700/1000000 symulacji.
# Zakończono 962800/1000000 symulacji.
# Zakończono 962900/1000000 symulacji.
# Zakończono 963000/1000000 symulacji.
# Zakończono 963100/1000000 symulacji.
# Zakończono 963200/1000000 symulacji.
# Zakończono 963300/1000000 symulacji.
# Zakończono 963400/1000000 symulacji.
# Zakończono 963500/1000000 symulacji.
# Zakończono 963600/1000000 symulacji.
# Zakończono 963700/1000000 symulacji.
# Zakończono 963800/1000000 symulacji.
# Zakończono 963900/1000000 symulacji.
# Zakończono 964000/1000000 symulacji.
# Zakończono 964100/1000000 symulacji.
# Zakończono 964200/1000000 symulacji.
# Zakończono 964300/1000000 symulacji.
# Zakończono 964400/1000000 symulacji.
# Zakończono 964500/1000000 symulacji.
# Zakończono 964600/1000000 symulacji.
# Zakończono 964700/1000000 symulacji.
# Zakończono 964800/1000000 symulacji.
# Zakończono 964900/1000000 symulacji.
# Zakończono 965000/1000000 symulacji.
# Zakończono 965100/1000000 symulacji.
# Zakończono 965200/1000000 symulacji.
# Zakończono 965300/1000000 symulacji.
# Zakończono 965400/1000000 symulacji.
# Zakończono 965500/1000000 symulacji.
# Zakończono 965600/1000000 symulacji.
# Zakończono 965700/1000000 symulacji.
# Zakończono 965800/1000000 symulacji.
# Zakończono 965900/1000000 symulacji.
# Zakończono 966000/1000000 symulacji.
# Zakończono 966100/1000000 symulacji.
# Zakończono 966200/1000000 symulacji.
# Zakończono 966300/1000000 symulacji.
# Zakończono 966400/1000000 symulacji.
# Zakończono 966500/1000000 symulacji.
# Zakończono 966600/1000000 symulacji.
# Zakończono 966700/1000000 symulacji.
# Zakończono 966800/1000000 symulacji.
# Zakończono 966900/1000000 symulacji.
# Zakończono 967000/1000000 symulacji.
# Zakończono 967100/1000000 symulacji.
# Zakończono 967200/1000000 symulacji.
# Zakończono 967300/1000000 symulacji.
# Zakończono 967400/1000000 symulacji.
# Zakończono 967500/1000000 symulacji.
# Zakończono 967600/1000000 symulacji.
# Zakończono 967700/1000000 symulacji.
# Zakończono 967800/1000000 symulacji.
# Zakończono 967900/1000000 symulacji.
# Zakończono 968000/1000000 symulacji.
# Zakończono 968100/1000000 symulacji.
# Zakończono 968200/1000000 symulacji.
# Zakończono 968300/1000000 symulacji.
# Zakończono 968400/1000000 symulacji.
# Zakończono 968500/1000000 symulacji.
# Zakończono 968600/1000000 symulacji.
# Zakończono 968700/1000000 symulacji.
# Zakończono 968800/1000000 symulacji.
# Zakończono 968900/1000000 symulacji.
# Zakończono 969000/1000000 symulacji.
# Zakończono 969100/1000000 symulacji.
# Zakończono 969200/1000000 symulacji.
# Zakończono 969300/1000000 symulacji.
# Zakończono 969400/1000000 symulacji.
# Zakończono 969500/1000000 symulacji.
# Zakończono 969600/1000000 symulacji.
# Zakończono 969700/1000000 symulacji.
# Zakończono 969800/1000000 symulacji.
# Zakończono 969900/1000000 symulacji.
# Zakończono 970000/1000000 symulacji.
# Zakończono 970100/1000000 symulacji.
# Zakończono 970200/1000000 symulacji.
# Zakończono 970300/1000000 symulacji.
# Zakończono 970400/1000000 symulacji.
# Zakończono 970500/1000000 symulacji.
# Zakończono 970600/1000000 symulacji.
# Zakończono 970700/1000000 symulacji.
# Zakończono 970800/1000000 symulacji.
# Zakończono 970900/1000000 symulacji.
# Zakończono 971000/1000000 symulacji.
# Zakończono 971100/1000000 symulacji.
# Zakończono 971200/1000000 symulacji.
# Zakończono 971300/1000000 symulacji.
# Zakończono 971400/1000000 symulacji.
# Zakończono 971500/1000000 symulacji.
# Zakończono 971600/1000000 symulacji.
# Zakończono 971700/1000000 symulacji.
# Zakończono 971800/1000000 symulacji.
# Zakończono 971900/1000000 symulacji.
# Zakończono 972000/1000000 symulacji.
# Zakończono 972100/1000000 symulacji.
# Zakończono 972200/1000000 symulacji.
# Zakończono 972300/1000000 symulacji.
# Zakończono 972400/1000000 symulacji.
# Zakończono 972500/1000000 symulacji.
# Zakończono 972600/1000000 symulacji.
# Zakończono 972700/1000000 symulacji.
# Zakończono 972800/1000000 symulacji.
# Zakończono 972900/1000000 symulacji.
# Zakończono 973000/1000000 symulacji.
# Zakończono 973100/1000000 symulacji.
# Zakończono 973200/1000000 symulacji.
# Zakończono 973300/1000000 symulacji.
# Zakończono 973400/1000000 symulacji.
# Zakończono 973500/1000000 symulacji.
# Zakończono 973600/1000000 symulacji.
# Zakończono 973700/1000000 symulacji.
# Zakończono 973800/1000000 symulacji.
# Zakończono 973900/1000000 symulacji.
# Zakończono 974000/1000000 symulacji.
# Zakończono 974100/1000000 symulacji.
# Zakończono 974200/1000000 symulacji.
# Zakończono 974300/1000000 symulacji.
# Zakończono 974400/1000000 symulacji.
# Zakończono 974500/1000000 symulacji.
# Zakończono 974600/1000000 symulacji.
# Zakończono 974700/1000000 symulacji.
# Zakończono 974800/1000000 symulacji.
# Zakończono 974900/1000000 symulacji.
# Zakończono 975000/1000000 symulacji.
# Zakończono 975100/1000000 symulacji.
# Zakończono 975200/1000000 symulacji.
# Zakończono 975300/1000000 symulacji.
# Zakończono 975400/1000000 symulacji.
# Zakończono 975500/1000000 symulacji.
# Zakończono 975600/1000000 symulacji.
# Zakończono 975700/1000000 symulacji.
# Zakończono 975800/1000000 symulacji.
# Zakończono 975900/1000000 symulacji.
# Zakończono 976000/1000000 symulacji.
# Zakończono 976100/1000000 symulacji.
# Zakończono 976200/1000000 symulacji.
# Zakończono 976300/1000000 symulacji.
# Zakończono 976400/1000000 symulacji.
# Zakończono 976500/1000000 symulacji.
# Zakończono 976600/1000000 symulacji.
# Zakończono 976700/1000000 symulacji.
# Zakończono 976800/1000000 symulacji.
# Zakończono 976900/1000000 symulacji.
# Zakończono 977000/1000000 symulacji.
# Zakończono 977100/1000000 symulacji.
# Zakończono 977200/1000000 symulacji.
# Zakończono 977300/1000000 symulacji.
# Zakończono 977400/1000000 symulacji.
# Zakończono 977500/1000000 symulacji.
# Zakończono 977600/1000000 symulacji.
# Zakończono 977700/1000000 symulacji.
# Zakończono 977800/1000000 symulacji.
# Zakończono 977900/1000000 symulacji.
# Zakończono 978000/1000000 symulacji.
# Zakończono 978100/1000000 symulacji.
# Zakończono 978200/1000000 symulacji.
# Zakończono 978300/1000000 symulacji.
# Zakończono 978400/1000000 symulacji.
# Zakończono 978500/1000000 symulacji.
# Zakończono 978600/1000000 symulacji.
# Zakończono 978700/1000000 symulacji.
# Zakończono 978800/1000000 symulacji.
# Zakończono 978900/1000000 symulacji.
# Zakończono 979000/1000000 symulacji.
# Zakończono 979100/1000000 symulacji.
# Zakończono 979200/1000000 symulacji.
# Zakończono 979300/1000000 symulacji.
# Zakończono 979400/1000000 symulacji.
# Zakończono 979500/1000000 symulacji.
# Zakończono 979600/1000000 symulacji.
# Zakończono 979700/1000000 symulacji.
# Zakończono 979800/1000000 symulacji.
# Zakończono 979900/1000000 symulacji.
# Zakończono 980000/1000000 symulacji.
# Zakończono 980100/1000000 symulacji.
# Zakończono 980200/1000000 symulacji.
# Zakończono 980300/1000000 symulacji.
# Zakończono 980400/1000000 symulacji.
# Zakończono 980500/1000000 symulacji.
# Zakończono 980600/1000000 symulacji.
# Zakończono 980700/1000000 symulacji.
# Zakończono 980800/1000000 symulacji.
# Zakończono 980900/1000000 symulacji.
# Zakończono 981000/1000000 symulacji.
# Zakończono 981100/1000000 symulacji.
# Zakończono 981200/1000000 symulacji.
# Zakończono 981300/1000000 symulacji.
# Zakończono 981400/1000000 symulacji.
# Zakończono 981500/1000000 symulacji.
# Zakończono 981600/1000000 symulacji.
# Zakończono 981700/1000000 symulacji.
# Zakończono 981800/1000000 symulacji.
# Zakończono 981900/1000000 symulacji.
# Zakończono 982000/1000000 symulacji.
# Zakończono 982100/1000000 symulacji.
# Zakończono 982200/1000000 symulacji.
# Zakończono 982300/1000000 symulacji.
# Zakończono 982400/1000000 symulacji.
# Zakończono 982500/1000000 symulacji.
# Zakończono 982600/1000000 symulacji.
# Zakończono 982700/1000000 symulacji.
# Zakończono 982800/1000000 symulacji.
# Zakończono 982900/1000000 symulacji.
# Zakończono 983000/1000000 symulacji.
# Zakończono 983100/1000000 symulacji.
# Zakończono 983200/1000000 symulacji.
# Zakończono 983300/1000000 symulacji.
# Zakończono 983400/1000000 symulacji.
# Zakończono 983500/1000000 symulacji.
# Zakończono 983600/1000000 symulacji.
# Zakończono 983700/1000000 symulacji.
# Zakończono 983800/1000000 symulacji.
# Zakończono 983900/1000000 symulacji.
# Zakończono 984000/1000000 symulacji.
# Zakończono 984100/1000000 symulacji.
# Zakończono 984200/1000000 symulacji.
# Zakończono 984300/1000000 symulacji.
# Zakończono 984400/1000000 symulacji.
# Zakończono 984500/1000000 symulacji.
# Zakończono 984600/1000000 symulacji.
# Zakończono 984700/1000000 symulacji.
# Zakończono 984800/1000000 symulacji.
# Zakończono 984900/1000000 symulacji.
# Zakończono 985000/1000000 symulacji.
# Zakończono 985100/1000000 symulacji.
# Zakończono 985200/1000000 symulacji.
# Zakończono 985300/1000000 symulacji.
# Zakończono 985400/1000000 symulacji.
# Zakończono 985500/1000000 symulacji.
# Zakończono 985600/1000000 symulacji.
# Zakończono 985700/1000000 symulacji.
# Zakończono 985800/1000000 symulacji.
# Zakończono 985900/1000000 symulacji.
# Zakończono 986000/1000000 symulacji.
# Zakończono 986100/1000000 symulacji.
# Zakończono 986200/1000000 symulacji.
# Zakończono 986300/1000000 symulacji.
# Zakończono 986400/1000000 symulacji.
# Zakończono 986500/1000000 symulacji.
# Zakończono 986600/1000000 symulacji.
# Zakończono 986700/1000000 symulacji.
# Zakończono 986800/1000000 symulacji.
# Zakończono 986900/1000000 symulacji.
# Zakończono 987000/1000000 symulacji.
# Zakończono 987100/1000000 symulacji.
# Zakończono 987200/1000000 symulacji.
# Zakończono 987300/1000000 symulacji.
# Zakończono 987400/1000000 symulacji.
# Zakończono 987500/1000000 symulacji.
# Zakończono 987600/1000000 symulacji.
# Zakończono 987700/1000000 symulacji.
# Zakończono 987800/1000000 symulacji.
# Zakończono 987900/1000000 symulacji.
# Zakończono 988000/1000000 symulacji.
# Zakończono 988100/1000000 symulacji.
# Zakończono 988200/1000000 symulacji.
# Zakończono 988300/1000000 symulacji.
# Zakończono 988400/1000000 symulacji.
# Zakończono 988500/1000000 symulacji.
# Zakończono 988600/1000000 symulacji.
# Zakończono 988700/1000000 symulacji.
# Zakończono 988800/1000000 symulacji.
# Zakończono 988900/1000000 symulacji.
# Zakończono 989000/1000000 symulacji.
# Zakończono 989100/1000000 symulacji.
# Zakończono 989200/1000000 symulacji.
# Zakończono 989300/1000000 symulacji.
# Zakończono 989400/1000000 symulacji.
# Zakończono 989500/1000000 symulacji.
# Zakończono 989600/1000000 symulacji.
# Zakończono 989700/1000000 symulacji.
# Zakończono 989800/1000000 symulacji.
# Zakończono 989900/1000000 symulacji.
# Zakończono 990000/1000000 symulacji.
# Zakończono 990100/1000000 symulacji.
# Zakończono 990200/1000000 symulacji.
# Zakończono 990300/1000000 symulacji.
# Zakończono 990400/1000000 symulacji.
# Zakończono 990500/1000000 symulacji.
# Zakończono 990600/1000000 symulacji.
# Zakończono 990700/1000000 symulacji.
# Zakończono 990800/1000000 symulacji.
# Zakończono 990900/1000000 symulacji.
# Zakończono 991000/1000000 symulacji.
# Zakończono 991100/1000000 symulacji.
# Zakończono 991200/1000000 symulacji.
# Zakończono 991300/1000000 symulacji.
# Zakończono 991400/1000000 symulacji.
# Zakończono 991500/1000000 symulacji.
# Zakończono 991600/1000000 symulacji.
# Zakończono 991700/1000000 symulacji.
# Zakończono 991800/1000000 symulacji.
# Zakończono 991900/1000000 symulacji.
# Zakończono 992000/1000000 symulacji.
# Zakończono 992100/1000000 symulacji.
# Zakończono 992200/1000000 symulacji.
# Zakończono 992300/1000000 symulacji.
# Zakończono 992400/1000000 symulacji.
# Zakończono 992500/1000000 symulacji.
# Zakończono 992600/1000000 symulacji.
# Zakończono 992700/1000000 symulacji.
# Zakończono 992800/1000000 symulacji.
# Zakończono 992900/1000000 symulacji.
# Zakończono 993000/1000000 symulacji.
# Zakończono 993100/1000000 symulacji.
# Zakończono 993200/1000000 symulacji.
# Zakończono 993300/1000000 symulacji.
# Zakończono 993400/1000000 symulacji.
# Zakończono 993500/1000000 symulacji.
# Zakończono 993600/1000000 symulacji.
# Zakończono 993700/1000000 symulacji.
# Zakończono 993800/1000000 symulacji.
# Zakończono 993900/1000000 symulacji.
# Zakończono 994000/1000000 symulacji.
# Zakończono 994100/1000000 symulacji.
# Zakończono 994200/1000000 symulacji.
# Zakończono 994300/1000000 symulacji.
# Zakończono 994400/1000000 symulacji.
# Zakończono 994500/1000000 symulacji.
# Zakończono 994600/1000000 symulacji.
# Zakończono 994700/1000000 symulacji.
# Zakończono 994800/1000000 symulacji.
# Zakończono 994900/1000000 symulacji.
# Zakończono 995000/1000000 symulacji.
# Zakończono 995100/1000000 symulacji.
# Zakończono 995200/1000000 symulacji.
# Zakończono 995300/1000000 symulacji.
# Zakończono 995400/1000000 symulacji.
# Zakończono 995500/1000000 symulacji.
# Zakończono 995600/1000000 symulacji.
# Zakończono 995700/1000000 symulacji.
# Zakończono 995800/1000000 symulacji.
# Zakończono 995900/1000000 symulacji.
# Zakończono 996000/1000000 symulacji.
# Zakończono 996100/1000000 symulacji.
# Zakończono 996200/1000000 symulacji.
# Zakończono 996300/1000000 symulacji.
# Zakończono 996400/1000000 symulacji.
# Zakończono 996500/1000000 symulacji.
# Zakończono 996600/1000000 symulacji.
# Zakończono 996700/1000000 symulacji.
# Zakończono 996800/1000000 symulacji.
# Zakończono 996900/1000000 symulacji.
# Zakończono 997000/1000000 symulacji.
# Zakończono 997100/1000000 symulacji.
# Zakończono 997200/1000000 symulacji.
# Zakończono 997300/1000000 symulacji.
# Zakończono 997400/1000000 symulacji.
# Zakończono 997500/1000000 symulacji.
# Zakończono 997600/1000000 symulacji.
# Zakończono 997700/1000000 symulacji.
# Zakończono 997800/1000000 symulacji.
# Zakończono 997900/1000000 symulacji.
# Zakończono 998000/1000000 symulacji.
# Zakończono 998100/1000000 symulacji.
# Zakończono 998200/1000000 symulacji.
# Zakończono 998300/1000000 symulacji.
# Zakończono 998400/1000000 symulacji.
# Zakończono 998500/1000000 symulacji.
# Zakończono 998600/1000000 symulacji.
# Zakończono 998700/1000000 symulacji.
# Zakończono 998800/1000000 symulacji.
# Zakończono 998900/1000000 symulacji.
# Zakończono 999000/1000000 symulacji.
# Zakończono 999100/1000000 symulacji.
# Zakończono 999200/1000000 symulacji.
# Zakończono 999300/1000000 symulacji.
# Zakończono 999400/1000000 symulacji.
# Zakończono 999500/1000000 symulacji.
# Zakończono 999600/1000000 symulacji.
# Zakończono 999700/1000000 symulacji.
# Zakończono 999800/1000000 symulacji.
# Zakończono 999900/1000000 symulacji.
# Zakończono 1000000/1000000 symulacji.
#
# --- Wyniki dla losowego agenta ---
# Liczba symulacji: 1000000
# Średnia całkowita nagroda na epizod: -85.94 (Std Dev: 341.69)
# Średnia liczba złapanych Pokémonów na epizod: 7.63 (Std Dev: 2.61)
# Maksymalna nagroda w epizodzie: 1543.30
# Minimalna nagroda w epizodzie: -1872.50
# Maksymalna liczba złapanych Pokémonów w epizodzie: 22
# Minimalna liczba złapanych Pokémonów w epizodzie: 0
#
# Symulacja losowego agenta zakończona.
#
# --- Generowanie wykresów Plotly dla losowego agenta ---
# Wykres rozkładu nagród losowego agenta został zapisany do 'random_agent_rewards_distribution.html'
# Wykres rozkładu złapanych Pokémonów losowego agenta został zapisany do 'random_agent_caught_distribution.html'
#
# Generowanie wykresów zakończone.
